# %%
import os
import json
import re
import requests
import nltk
import pandas as pd
from unidecode import unidecode
from pandas.parser import CParserError
from bs4 import BeautifulSoup
from xml.etree import ElementTree

# %%
# Full request parameters. Two "all" parameters are allowed per request.
"""
http://wits.worldbank.org/API/V1/SDMX/V21/datasource/TRN/
reporter/{all|reporter code list}
/partner/{all|partner code list}
/product/{ALL|product code list}
/year/{All|Year List
/datatype/{reported|aveestimated}}"""
    
    
    
countries_url = "http://wits.worldbank.org/API/V1/wits/datasource/trn/country/ALL"
nomenclature_url = "http://wits.worldbank.org/API/V1/wits/datasource/trn/nomenclature/" #H0 through H4
products_url = "http://wits.worldbank.org/API/V1/wits/datasource/trn/product/all" # nomenclaturecode is HS

# Country, product, nomenclature, partner list, 
# number preferential agreements, is specific duty expression estimated, last update
data_available_url = "http://wits.worldbank.org/API/V1/wits/datasource/trn/dataavailability/"

# %%
# US 840. Canada 124. EU 918. 710 South Africa
# Make sure partner is taken from Partner list in data availability
test_url = "http://wits.worldbank.org/API/V1/SDMX/V21/datasource/TRN/reporter/918/partner/710/product/ALL/year/2008/datatype/reported"

# %%
res = requests.get(test_url)

# %%
root = ElementTree.fromstring(res.content)
series = root.findall(".//Series")
obs = root.findall(".//Obs")
dataset = root.findall(".//Dataset")

# %%
first = series[0].findall(".//Obs")[0].attrib
attribute = series[0].attrib
combined = {**first,**attribute}
df = pd.DataFrame(columns=list(combined.keys()))

data = [{**s.findall(".//Obs")[0].attrib,**s.attrib}  for s in series]

df = df.append(data)

# %%
df.head()
# Out:
#   TIME_PERIOD NBR_NA_LINES TARIFFTYPE PARTNER TOTALNOOFLINES  DATATYPE  \
# 0        2008            0       PREF     710              3  Reported
# 1        2008            0       PREF     710              4  Reported
# 2        2008            1       PREF     710              2  Reported
# 3        2008            2       PREF     710              3  Reported
# 4        2008            2       PREF     710              3  Reported
#
#            OBS_VALUE REPORTER MIN_RATE NBR_MFN_LINES          MAX_RATE  \
# 0  0.400000015894572      918        0             1  1.20000004768372
# 1  0.300000011920929      918        0             1  1.20000004768372
# 2                  0      918        0             1                 0
# 3                  0      918        0             1                 0
# 4                  0      918        0             1                 0
#
#   OBS_VALUE_MEASURE FREQ      SUM_OF_RATES NOMENCODE PRODUCTCODE  \
# 0     SimpleAverage    A  1.20000004768372        H3      010110
# 1     SimpleAverage    A  1.20000004768372        H3      010190
# 2     SimpleAverage    A                 0        H3      010391
# 3     SimpleAverage    A                 0        H3      010392
# 4     SimpleAverage    A                 0        H3      010410
#
#   NBR_PREF_LINES
# 0              2
# 1              3
# 2              1
# 3              2
# 4              2

# %%
df.describe()
# Out:
#        TIME_PERIOD NBR_NA_LINES TARIFFTYPE PARTNER TOTALNOOFLINES  DATATYPE  \
# count         3562         3562       3562    3562           3562      3562
# unique           1           27          1       1             44         1
# top           2008            0       PREF     710              1  Reported
# freq          3562         3363       3562    3562           1561      3562
#
#        OBS_VALUE REPORTER MIN_RATE NBR_MFN_LINES MAX_RATE OBS_VALUE_MEASURE  \
# count       3562     3562     3562          3562     3562              3562
# unique       101        1       44            25       65                 1
# top            0      918        0             0        0     SimpleAverage
# freq        3306     3562     3349          2983     3306              3562
#
#         FREQ SUM_OF_RATES NOMENCODE PRODUCTCODE NBR_PREF_LINES
# count   3562         3562      3562        3562           3562
# unique     1          104         1        3562             39
# top        A            0        H3      520532              1
# freq    3562         3306      3562           1           1798

# %%
df[df.MAX_RATE==df.MIN_RATE].count()
# Out:
# TIME_PERIOD          3489
# NBR_NA_LINES         3489
# TARIFFTYPE           3489
# PARTNER              3489
# TOTALNOOFLINES       3489
# DATATYPE             3489
# OBS_VALUE            3489
# REPORTER             3489
# MIN_RATE             3489
# NBR_MFN_LINES        3489
# MAX_RATE             3489
# OBS_VALUE_MEASURE    3489
# FREQ                 3489
# SUM_OF_RATES         3489
# NOMENCODE            3489
# PRODUCTCODE          3489
# NBR_PREF_LINES       3489
# dtype: int64

# %%
df[df.MAX_RATE=="0"].count()
# Out:
# TIME_PERIOD          3306
# NBR_NA_LINES         3306
# TARIFFTYPE           3306
# PARTNER              3306
# TOTALNOOFLINES       3306
# DATATYPE             3306
# OBS_VALUE            3306
# REPORTER             3306
# MIN_RATE             3306
# NBR_MFN_LINES        3306
# MAX_RATE             3306
# OBS_VALUE_MEASURE    3306
# FREQ                 3306
# SUM_OF_RATES         3306
# NOMENCODE            3306
# PRODUCTCODE          3306
# NBR_PREF_LINES       3306
# dtype: int64

# %%
len(df[df.MAX_RATE==""]) # 96 missing or empty max rates
# Out:
# 96

# %%
df[['NOMENCODE','PRODUCTCODE']]
# Out:
#      NOMENCODE PRODUCTCODE
# 0           H3      010110
# 1           H3      010190
# 2           H3      010391
# 3           H3      010392
# 4           H3      010410
# 5           H3      010420
# 6           H3      010511
# 7           H3      010512
# 8           H3      010519
# 9           H3      010594
# 10          H3      010599
# 11          H3      010619
# 12          H3      010639
# 13          H3      020311
# 14          H3      020312
# 15          H3      020319
# 16          H3      020321
# 17          H3      020322
# 18          H3      020329
# 19          H3      020410
# 20          H3      020421
# 21          H3      020422
# 22          H3      020423
# 23          H3      020430
# 24          H3      020441
# 25          H3      020442
# 26          H3      020443
# 27          H3      020450
# 28          H3      020500
# 29          H3      020680
# ...        ...         ...
# 3532        H3      960719
# 3533        H3      960720
# 3534        H3      960810
# 3535        H3      960820
# 3536        H3      960831
# 3537        H3      960839
# 3538        H3      960840
# 3539        H3      960850
# 3540        H3      960860
# 3541        H3      960891
# 3542        H3      960899
# 3543        H3      960910
# 3544        H3      960920
# 3545        H3      960990
# 3546        H3      961000
# 3547        H3      961100
# 3548        H3      961210
# 3549        H3      961220
# 3550        H3      961310
# 3551        H3      961320
# 3552        H3      961380
# 3553        H3      961390
# 3554        H3      961400
# 3555        H3      961511
# 3556        H3      961519
# 3557        H3      961590
# 3558        H3      961610
# 3559        H3      961620
# 3560        H3      961700
# 3561        H3      961800
#
# [3562 rows x 2 columns]

# %%
# WITS UNCTAD TRAINS provides graphical query interface with API-like url structure
gui_url = "http://wits.worldbank.org/tariff/trains/en/country/USA/year/2014/pagenumber/1/pageSize/134684"
res = requests.get(gui_url)

# %%
soup = BeautifulSoup(res.text,"html.parser")

# %%
scripts = soup.find_all("script")
len(scripts)
# Out:
# 19

# %%
p = re.search("(localdata: \[)(.*)",scripts[7].text)
data = p.group(2)

# %%
fields = ['ProductCode','ProductDescription','Partner','PartnerName','AdValorem','MeasureName','NonAdValorem','AffectedPartners']
rows = [s+"," for s in data.split("},")]


output = []
for row in rows:
    r = {}
    for f in fields:
        s = re.search("(?<="+f+" :)(.*?)(?=,)",row)
        value = s.group(0).replace("\"","")
        #print(f+":"+value)
        r.update({f:value})
    output.append(r)
print(r)
# Out:
# {'MeasureName': ' Non-MFN duty rate for countries excluded from Most-Favoured- Nation (MFN) treatement  ', 'NonAdValorem': '   ', 'AffectedPartners': '   }\r', 'ProductCode': ' 97060000  ', 'PartnerName': ' Non-MFN Countries for USA: 2006  ', 'AdValorem': ' 0.00  ', 'ProductDescription': ' Antiques of an age exceeding one hundred years  ', 'Partner': ' N76  '}

# %%
f = "ProductCode"
s = re.search("(?<="+f+" :)(.*?)(?=,)",rows[0])
value = s.group(0).replace("\"","")
value
# Out:
# ' 01012100  '

# %%
p = re.search('var totalRecords= ([0-9]{1,6})',scripts[7].text)
p.group(0)
# Out:
# 'var totalRecords= 134684'

# %%
dat = pd.DataFrame(output)

# %%
nav_unique = dat.NonAdValorem.unique()
units = """cent_tariff: {<CD><NN>}
           cent_tariff: {<CD><JJ><NN>}
           cent_tariff: {<CD><NNS><DT>}
           dollar_tariff:{<$>?<CD>}
           dollar_tariff:{<VBZ><CD><NN>}
           content:{<IN><DT><NN>}
           content:{<IN><NN><NN>}
           content:{<IN><JJ><NNS>}
           content:{<IN><NN>}
           """ # 6.6 cents/kg
percent = "price:{<$>?<CD>}" # $ 1.64/kg
content = "<IN<NN><NN>" #on molybdenum content
extra_feature = "<IN><DT><NN>" # on the case

# value currency_unit weight_unit 
cp = nltk.RegexpParser(units)
for n in nav_unique:
    pos = nltk.pos_tag(nltk.word_tokenize(n))
    #print(cp.parse(pos))

# %%
dat[dat.NonAdValorem!='   ']
# Out:
#         AdValorem AffectedPartners  \
# 49         1.96
# 50         0.30
# 51         0.12
# 68         1.63
# 72         0.30
# 73         0.12
# 90         1.64
# 92         0.28
# 93         0.11
# 110        1.53
# 115        1.46
# 117        2.32
# 119        3.23
# 120        0.94
# 138        4.16
# 140        0.58
# 158        2.57
# 160        0.38
# 178        1.71
# 180        0.37
# 198        1.62
# 200        0.19
# 218        0.84
# 220        0.42
# 238        1.85
# 240        1.51
# 258       13.29
# 260        1.05
# 278        9.26
# 394        0.94
# ...           ...              ...
# 133583
# 133601
# 133603     7.92
# 133611     4.41
# 133620   118.28
# 133623     0.41
# 133624
# 133641
# 133643
# 133660
# 133663
# 133666     6.17
# 133683    36.67
# 133686     1.85
# 133688     0.55
# 133692    40.40
# 133944
# 133961
# 133982
# 133999
# 134020
# 134037
# 134039     3.03
# 134056    35.32
# 134077     6.66
# 134094    55.63
# 134117     1.86
# 134134    33.26
# 134136     6.25
# 134153    51.52
#
#                                               MeasureName  \
# 49       Non-MFN duty rate for countries excluded from...
# 115                                        4.4 cents/kg     N76
# 117                                        4.4 cents/kg     N76
# 119                                             $3/head     N76
# 120                                       68 cents/head     000
# 138                                             $3/head     N76
# 140                                      0.9 cents each     000
# 158                                        4 cents each     N76
# 160                                      0.9 cents each     000
# 178                                        4 cents each     N76
# 180                                      0.9 cents each     000
# 198                                        4 cents each     N76
# 200                                      0.9 cents each     000
# 218                                        4 cents each     N76
# 220                                      0.9 cents each     000
# 238                                        4 cents each     N76
# 240                                          2 cents/kg     000
# 258                                       17.6 cents/kg     N76
# 260                                          2 cents/kg     000
# 278                                       17.6 cents/kg     N76
# 394                                        4.4 cents/kg     000
# ...                                                   ...     ...
# 133583   The rate applicable to each article in the ab...   000
# 133601                                The rate applicable   N76
# 133603                            0.4 cents each + 2.7%     000
# 133611                            0.2 cents each + 1.8%     410
# 133620                               6 cents each + 40%     N76
# 133623                                   20 cents/gross     N76
# 133624                            0.4 cents each + 2.7%     000
# 133641                               6 cents each + 40%     N76
# 133643                         20 cents/thousand + 3.5%     000
# 133660                             $2.50/thousand + 40%     N76
# 133663                               6 cents each + 40%     N76
# 133666                            14 cents/gross + 4.3%     000
# 133683                             50 cents/gross + 30%     N76
# 133686                                   20 cents/gross     N76
# 133688                                    6 cents/gross     N76
# 133692                             50 cents/gross + 30%     N76
# 133944                            0.4 cents each + 3.2%     000
# 133961                               5 cents each + 60%     N76
# 133982                            0.3 cents each + 3.2%     000
# 133999                               5 cents each + 60%     N76
# 134020                              0.5 cents each + 3%     000
# 134037                               5 cents each + 60%     N76
# 134039                            14.4 cents/gross + 2%     000
# 134056                                $1.44/gross + 25%     N76
# 134077                          28.8 cents/gross + 4.6%     000
# 134094                                $2.88/gross + 35%     N76
# 134117                           9.7 cents/gross + 1.3%     000
# 134134                                $1.44/gross + 25%     N76
# 134136                          28.8 cents/gross + 4.6%     000
# 134153                                $2.88/gross + 35%     N76
#
#                                PartnerName  ProductCode  \
# 49       Non-MFN Countries for USA: 2006     01022920
# 50                                 World     01022940
# 51                             Australia     01022940
# 68       Non-MFN Countries for USA: 2006     01022940
# 72                                 World     01023900
# 73                             Australia     01023900
# 90       Non-MFN Countries for USA: 2006     01023900
# 92                                 World     01029000
# 93                             Australia     01029000
# 110      Non-MFN Countries for USA: 2006     01029000
# 115      Non-MFN Countries for USA: 2006     01039100
# 117      Non-MFN Countries for USA: 2006     01039200
# 119      Non-MFN Countries for USA: 2006     01041000
# 120                                World     01042000
# 138      Non-MFN Countries for USA: 2006     01042000
# 140                                World     01051100
# 158      Non-MFN Countries for USA: 2006     01051100
# 160                                World     01051200
# 178      Non-MFN Countries for USA: 2006     01051200
# 180                                World     01051300
# 198      Non-MFN Countries for USA: 2006     01051300
# 200                                World     01051400
# 218      Non-MFN Countries for USA: 2006     01051400
# 220                                World     01051500
# 238      Non-MFN Countries for USA: 2006     01051500
# 240                                World     01059400
# 258      Non-MFN Countries for USA: 2006     01059400
# 260                                World     01059900
# 278      Non-MFN Countries for USA: 2006     01059900
# 394                                World     02011005
# ...                                    ...          ...
# 133583                             World     96085000
# 133601   Non-MFN Countries for USA: 2006     96085000
# 133603                             World     96086000
# 133611                               Korea   96086000
# 133620   Non-MFN Countries for USA: 2006     96086000
# 133623   Non-MFN Countries for USA: 2006     96089100
# 133624                             World     96089920
# 133641   Non-MFN Countries for USA: 2006     96089920
# 133643                             World     96089930
# 133660   Non-MFN Countries for USA: 2006     96089930
# 133663   Non-MFN Countries for USA: 2006     96089940
# 133666                             World     96091000
# 133683   Non-MFN Countries for USA: 2006     96091000
# 133686   Non-MFN Countries for USA: 2006     96092020
# 133688   Non-MFN Countries for USA: 2006     96092040
# 133692   Non-MFN Countries for USA: 2006     96099080
# 133944                             World     96140025
# 133961   Non-MFN Countries for USA: 2006     96140025
# 133982                             World     96140028
# 133999   Non-MFN Countries for USA: 2006     96140028
# 134020                             World     96140098
# 134037   Non-MFN Countries for USA: 2006     96140098
# 134039                             World     96151110
# 134056   Non-MFN Countries for USA: 2006     96151110
# 134077                             World     96151130
# 134094   Non-MFN Countries for USA: 2006     96151130
# 134117                             World     96151920
# 134134   Non-MFN Countries for USA: 2006     96151920
# 134136                             World     96151940
# 134153   Non-MFN Countries for USA: 2006     96151940
#
#                                        ProductDescription
# 49           Cows imported specially for dairy purposes
# 50       Live cattle other than purebred or those impo...
# 51       Live cattle other than purebred or those impo...
# 68       Live cattle other than purebred or those impo...
# 72                                           Live buffalo
# 73                                           Live buffalo
# 90                                           Live buffalo
# 92                                    Live bovine animals
# 93                                    Live bovine animals
# 110                                   Live bovine animals
# 115                                            Live swine
# 117                                            Live swine
# 119                                          Live sheep
# 120                                          Live goats
# 138                                          Live goats
# 140          Live chickens weighing not over 185 g each
# 158          Live chickens weighing not over 185 g each
# 160      Live turkeys weighing not more than over 185 ...
# 178      Live turkeys weighing not more than over 185 ...
# 180                                            Live ducks
# 198                                            Live ducks
# 200                                            Live geese
# 218                                            Live geese
# 220                                     Live guinea fowls
# 238                                     Live guinea fowls
# 240                               Live Poultry;Chickens
# 258                               Live Poultry;Chickens
# 260                                            Live ducks
# 278                                            Live ducks
# 394                           Bovine carcasses and halves
# ...                                                   ...
# 133583                                       Sets of pens
# 133601                                       Sets of pens
# 133603                        Refills for ball point pens
# 133611                        Refills for ball point pens
# 133620                        Refills for ball point pens
# 133623                          Pen nibs and nib points
# 133624   Refill cartridges for pens (o/than ball point...
# 133641   Refill cartridges for pens (o/than ball point...
# 133643                        Balls for ball point pens
# 133660                        Balls for ball point pens
# 133663                                              Parts
# 133666                                  Pencils & crayons
# 133683                                  Pencils & crayons
# 133686                                       Pencil leads
# 133688                                       Pencil leads
# 133692         Pencils & crayons (o/than in rigid sheath)
# 133944   Smoking pipes (o/than roughly shaped blocks o...
# 133961   Smoking pipes (o/than roughly shaped blocks o...
# 133982          Smoking pipes and pipe bowls (o/than wood
# 133999          Smoking pipes and pipe bowls (o/than wood
# 134020   Cigar or cigarette holders o/than of metal; p...
# 134037   Cigar or cigarette holders o/than of metal; p...
# 134039                                              Combs
# 134056                                              Combs
# 134077                                              Combs
# 134094                                              Combs
# 134117                                              Combs
# 134134                                              Combs
# 134136                                              Combs
# 134153                                              Combs
#
# [5334 rows x 8 columns]

# %% [markdown]
# Create dataset of all Non-ad valorem tariffs
# --

# %%
data_dir = "D:/Users/cmarciniak/Documents/macmap/data/unctad/specific"
files = os.listdir(data_dir)

# %%
df = pd.DataFrame()
for f in files:
    try:
        file = os.path.join(data_dir,f)
        data = pd.read_csv(file,encoding='latin-1',dtype='object')
        subset = data[data.NonAdValorem!='   ']
        df = df.append(subset)
    except CParserError:
        print("Error ocurred in file: "+f)
# Out:
# Error ocurred in file: JOR2003.csv

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1616659 entries, 214 to 44156
# Data columns (total 11 columns):
# Unnamed: 0            1616659 non-null object
# AdValorem             1616659 non-null object
# AffectedPartners      1616659 non-null object
# MeasureName           1616659 non-null object
# NonAdValorem          1616659 non-null object
# Partner               1616659 non-null object
# PartnerName           1616659 non-null object
# ProductCode           1616659 non-null object
# ProductDescription    1616659 non-null object
# Year                  1616659 non-null object
# ISO3Code              1616659 non-null object
# dtypes: object(11)
# memory usage: 148.0+ MB

# %%
def lookup(key,dictionary):
    val = ''
    try:
        val = dictionary[key]
    except KeyError:
        pass
    return val

# %%
currency_codes = {
	'F': 'Aruban Florin',
    'AMD':'Armenian Dram',
	'BD': 'Local Currency', 
	'DH':'Arab Emirates Dirham',
	'AED':'Arab Emirates Dirham',
	'DLARES':'USD',
	'$':'USD',
	'USD':'USD',
	'EUR':'Euro',
    'EURO':'Euro',
    'BHD':'Bahraini Dinar',
	'BSD':'Bahamian Dollar', 
	'KM':'Bosnian Mark',
	'BZD':'Belize Dollar',
	'BMD':'Bermudan Dollar',
	'Bolivian':'Bolivian Boliviano',
	'C':'cents',
	'CENTS':'cents',
	'CFA':'Central African Franc',
	'FR.':'Local Franc',
	'SFR':'Swiss Franc',
	'RMB':'Chinese Yuan',
	'YUAN':'Chinese Yuan',
	'CNY':'Chinese Yuan',
	'NZD':'New Zealand Dollar',
	'CYP':'Cypriot Pound',
	'C£':'Cypriot Pound',
	'DA':'Algerian Dinar',
    'DR':'Dominican Peso',
	'EGP':'Egyptian Pound',
	'POUND':'Local Pound',
	'LE':'Egyptian Pound',
	'EGL':'Egyptian Pound',
	'ECU':'European Currency Unit',
	'FJD':'Fijian Dollar',
	'GMD':'Gambian Dalasi',
	'RS':'Local Rupee',
	'ISK':'Iceland Krona',
	'SDR':'Special Drawing Right',
	'KR':'Swedish Kroner',
	'NIS':'Israeli New Sheqel',
	'YEN':'Japanese Yen',
	'Y':'Japanese Yen',
	'KES':'Kenyan Shilling',
	'SHS.':'Kenyan Shilling',
    'SH':'Shilling',
	'XCD':'East Caribbean Dollar',
	'WON':'Korean Won',
	'LYH':'Libyan Dinar',
	'LYD':'Libyan Dinar',
	'DINAR':'Libyan Dinar',
	'S':'Peruvian Sole',
	'RM':'Malaysian Ringgit',
	'M$':'Malaysian Ringgit',
	'NGN':'Nigerian Naira',
	'NK':'Norwegian Kroner',
	'NOK':'Norwegian Kroner',
	'KRONE':'Norwegian Kroner',
	'BALBOA':'Panamanian Balboa',
	'SAR':'Saudi Riyal',
	'SR':'Saudi Riyal',
	'SGD':'Singaporean Dollar',
	'S$':'Singaporean Dollar',
	'SBD':'Solomon Island Dollar',
	'SIT':'Slovenian Tolar',
	'SR':'Saudi Riyal',
	'BHT':'Thai Baht',
	'BAHTS':'Thai Baht',
	'B':'Thai Baht',
	'AUD':'Australian Dollar',
    'A$':'Australian Dollar',
	'NT$':'New Taiwan Dollar',
	"BOLIVARES":"Bolivian Bolivar",
	"SAT$":"Samoan Tala",
	"ZAR":"South African Rand",
	"RAND":"South African Rand"
}

units = {
    'KILOGRAMO':'kg',
	'KG':'kg',
	'LI':'litre',
	'LITRE':'liter',
    'LITER':'liter',
	'DOZEN': 'dozen',
    'DOZ':'dozen',
	'HL':'hectoliter',
	'SQUARE METER':'square meter',
	'SQM':'square meter',
	'SQ.MTR.':'square meter',
	'SQ. METRE':'square meter',
	'TONNE':'tonne',
	'T':'tonne',
	'KILOLITRE':'kiloliter',
	'KL': 'kilolitre',
	'SZT':'Polish sztych',
    'GALLON':'gallon',
    'GAL.':'gallon',
	'PAR':'pair',
	'M²':'square meter',
    'PCS':'pieces',
    'CM':'centimeters',
    'TON':'tonne',
    'ITEMS':'items',
    'UNIT':'unit',
    'M2':'square meter',
    'SM3':'standard cubic meter',
    'KGS':'kg',
    'PCE':'piece',
    'PIECE':'piece',
    'KILO':'kg',
    'KW':'kilowatt',
    'IMP.GAL': 'imperial gallon',
    'DAL':'dekaliter',
    'PRS':'pairs',
    'L':'liter',
    'LAA':'liters absolute alcohol'
    
}

operators = {
	'but not less than': '>=',
	'OR': 'OR',
	'+': 'AND',
    'AND':'AND',
	'PLUS':'AND',
	'MAX.':'max',
	'MIN.':'min',
    'MIN':'min',
	'MINIMUM':'min',
	'MAKSIMUM':"max",
	'QUOTA':'quota',
	'HIGHER':'>'
}

# %%
nav_unique = df.NonAdValorem.unique()
patterns = """
        
           dollar_tariff:{<$><CD><NN>}
           dollar_tariff:{<VBZ><CD><NN>}
           numeric_component: {<CD><NN>}
           numeric_component: {<CD><NNP>}
           cent_tariff: {<CD><JJ><NN>}
           cent_tariff: {<CD><NNS><DT>}
           dollar_tariff:{<$>?<CD>}
           content:{<IN><DT><NN>}
           content:{<IN><NN><NN>}
           content:{<IN><JJ><NNS>}
           weight_unit:{<IN><NN>}
           weight_unit:{<NNP><NN>}
           qualifier:{<NNP>}
           """ # 6.6 cents/kg
percent = "price:{<$>?<CD>}" # $ 1.64/kg
content = "<IN<NN><NN>" #on molybdenum content
extra_feature = "<IN><DT><NN>" # on the case

# value currency_unit weight_unit 
cp = nltk.RegexpParser(patterns)
trees2 = []
for n in nav_unique:
    items = {}
    i = 1
    j = 1
    items['text'] = n
    n = n.replace("/"," ").upper()
    pos = nltk.pos_tag(nltk.word_tokenize(n))
    tree = cp.parse(pos)
    for subtree in tree.subtrees():
        if subtree.label()=="numeric_component" and subtree[1][0]=='%':
            items['advalorem_component'+str(i)] = subtree[0][0]
            i = i+1
        if subtree.label()=="numeric_component" and lookup(subtree[1][0],operators)!="":
            items['advalorem_component'+str(i)] = subtree[0][0]
# 10                            12 Acc f 4.44 p.p 20 stks
# 11                                 0 Acc f 61.40 per hl
# 12                                 0 Acc f 33.50 per hl
# 13                                 0 Acc f 38.20 per hl
# 14                                        Misssing Rate
# 15       f 7.00 per rol van 38 cm middel- lijn of gede...
# 16         f 1.00 per rol van 18 cm of gedeelte daarvan
# 17                                                    0
# 18                                        Not available
# 19                        f 30 per hl Acc f 1844 per hl
# 20                         f 80 per hl Acc f 353 per hl
# 21                      f 30 per hl ad Acc f 1844 perhl
# 22                      Ivf 30 per hl Acc f 1844 per hl
# 23                            12 Acc f 6.35 per 20 stks
# 24       f 7.00 per rol van 38 cm middel- lijn of gede...
# 25                                           Prohibited
# 26                                   Rate Not Available
# 27                                        Not Available
# 28                                   Rate not available
# 29                                         Missing rate
# ...                                                   ...
# 102491                                       US$2.50/kg
# 102496                                         US$20/kg
# 102500                                        US$0.40/L
# 102501                                          $0.40/L
# 102503                                          $0.36/L
# 102506                                         US$1/LAA
# 102507                                           US$2/L
# 102508                                        US$5/1000
# 102513                                               US$0
# 102514                                        US$0.36/L
# 102515                                  $5/L or $10/LAA
# 102518                                         $0.15/m3
# 102533                                       US$ 0.50/L
# 102534                                         US$ 5/Kg
# 102535                                      US$ 2.50/Kg
# 102542                                            3c/Kg
# 102545                                     US$ 1.00/LAA
# 102546                                     US$ 0.05/LAA
# 102547                                    US$ 1.00/ LAA
# 102548                                       US$ 0.05/L
# 102549                                       US$ 1.00/L
# 102550                      US$ 5.00/L or US$ 10.00/LAA
# 102551                           US$ 20/1000 cigarettes
# 102553                                         $0.05/m3
# 102554                                            1c/Kg
# 102555                                      US$ 0.02/Kg
# 102556                                         $0.02/Kg
# 102558                                          5.5c/Kg
# 102559                                         $2.50/Kg
# 102563                                      US$ 0.50/Kg
#
#                            unit value1 value2 value3 value4 value5 value6  \
# 0                    hectoliter     30    NaN    NaN    NaN    NaN    NaN
# 1                            kg   1.50    NaN    NaN    NaN    NaN    NaN
# 2                    hectoliter     30   1844    NaN    NaN    NaN    NaN
# 3                    hectoliter     10    NaN    NaN    NaN    NaN    NaN
# 4                    hectoliter    169    NaN    NaN    NaN    NaN    NaN
# 5                    hectoliter     80    353    NaN    NaN    NaN    NaN
# 6                    hectoliter    520    NaN    NaN    NaN    NaN    NaN
# 7                    hectoliter    400    NaN    NaN    NaN    NaN    NaN
# 8                    hectoliter    100    NaN    NaN    NaN    NaN    NaN
# 9                    hectoliter    150    NaN    NaN    NaN    NaN    NaN
# 10                          NaN     12   4.44     20    NaN    NaN    NaN
# 11                   hectoliter      0  61.40    NaN    NaN    NaN    NaN
# 12                   hectoliter      0  33.50    NaN    NaN    NaN    NaN
# 13                   hectoliter      0  38.20    NaN    NaN    NaN    NaN
# 14                          NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 15                  centimeters   7.00    NaN    NaN    NaN    NaN    NaN
# 16                  centimeters   1.00    NaN    NaN    NaN    NaN    NaN
# 17                          NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 18                          NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 
# 37                       $100.00/unit                       unit    NaN
# 38                        $25.00/unit                       unit    NaN
# 45                       not provided                        NaN    NaN
# 46                         PROHIBITED                        NaN    NaN
# 71                      Special goods                        NaN    NaN
# 1405                     Missing Rate                        NaN    NaN
# 1945                                  3                      NaN    NaN
# 1953                                550                      NaN    NaN
# 1954                                 15                      NaN    NaN
# 1955                                  5                      NaN    NaN
# 2071        250 US dollar per 1000 kg                         kg    NaN
# 2072     256.67 US dollar per 1000 kg                         kg    NaN
# 2073        240 US dollar per 1000 kg                         kg    NaN
# 2074        203 US dollar per 1000 kg                         kg    NaN
# 2075        171 US dollar per 1000 kg                         kg    NaN
# 2076        140 US dollar per 1000 kg                         kg    NaN
# 2077        248 US dollar per 1000 kg                         kg    NaN
# 2078        227 US dollar per 1000 kg                         kg    NaN
# 2079        205 US dollar per 1000 kg                         kg    NaN
# 2080        183 US dollar per 1000 kg                         kg    NaN
# 2081        162 US dollar per 1000 kg                         kg    NaN
# ...                                 ...                      ...    ...
# 102486                      US$0.20/L                      liter    NaN
# 102487                      US$0.16/L                      liter    NaN
# 102488                     US$0.02/kg                         kg    NaN
# 102491                     US$2.50/kg                         kg    NaN
# 102496                       US$20/kg                         kg    NaN
# 102500                      US$0.40/L                      liter    NaN
# 102501                        $0.40/L                      liter    NaN
# 102503                        $0.36/L                      liter    NaN
# 102506                       US$1/LAA    liters absolute alcohol    NaN
# 102507                         US$2/L                      liter    NaN
# 102508                      US$5/1000                        NaN    NaN
# 102513                             US$0                      NaN    NaN
# 102514                      US$0.36/L                      liter    NaN
# 102515                $5/L or $10/LAA    liters absolute alcohol    NaN
# 102533                     US$ 0.50/L                      liter    NaN
# 102534                       US$ 5/Kg                         kg    NaN
# 102535                    US$ 2.50/Kg                         kg    NaN
# 102542                          3c/Kg                         kg    NaN
# 102545                   US$ 1.00/LAA    liters absolute alcohol    NaN
# 102546                   US$ 0.05/LAA    liters absolute alcohol    NaN
# 102547                  US$ 1.00/ LAA    liters absolute alcohol    NaN
# 102548                     US$ 0.05/L                      liter    NaN
# 102549                     US$ 1.00/L                      liter    NaN
# 102550    US$ 5.00/L or US$ 10.00/LAA    liters absolute alcohol    NaN
# 102554                          1c/Kg                         kg    NaN
# 102555                    US$ 0.02/Kg                         kg    NaN
# 102556                       $0.02/Kg                         kg    NaN
# 102558                        5.5c/Kg                         kg    NaN
# 102559                       $2.50/Kg                         kg    NaN
# 102563                    US$ 0.50/Kg                         kg    NaN
#
#        value2 value3 value4 value5 value6 value7 value8
# 14        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 17        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 18        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 25        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 26        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 27        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 28        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 29        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 30        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 37        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 38        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 45        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 46        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 71        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1405      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1945      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1953      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1954      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1955      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2071      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2072      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2073      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2074      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2075      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2076      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2077      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2078      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2079      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2080      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2081      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...       ...    ...    ...    ...    ...    ...    ...
# 102486    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102487    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102488    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102491    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102496    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102500    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102501    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102503    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102506    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102507    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102508    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102513    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102514    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102515    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102533    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102534    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102535    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102542    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102545    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102546    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102547    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102548    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102549    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102550    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102554    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102555    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102556    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102558    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102559    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 102563    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# [28631 rows x 17 columns]
