# %%
import os
import pandas as pd
import blaze

# %%
data_dir = "D:/Users/cmarciniak/Documents/macmap/data/usitc"

# %%
tariffs = os.path.join(data_dir,"tariff_database_2015.txt")
data = pd.read_table(tariffs,delimiter="|",dtype="object")

# %%
for col in data.columns:
    print(col)
# Out:
# hts8
# brief_description
# quantity_1_code
# quantity_2_code
# wto_binding_code
# mfn_text_rate
# mfn_rate_type_code
# mfn_ave
# mfn_ad_val_rate
# mfn_specific_rate
# mfn_other_rate
# col1_special_text
# col1_special_mod
# gsp_indicator
# gsp_ctry_excluded
# apta_indicator
# civil_air_indicator
# nafta_canada_ind
# nafta_mexico_ind
# mexico_rate_type_code
# mexico_ad_val_rate
# mexico_specific_rate
# cbi_indicator
# cbi_ad_val_rate
# cbi_specific_rate
# agoa_indicator
# cbtpa_indicator
# cbtpa_rate_type_code
# cbtpa_ad_val_rate
# cbtpa_specific_rate
# israel_fta_indicator
# atpa_indicator
# atpa_ad_val_rate
# atpa_specific_rate
# atpdea_indicator
# jordan_indicator
# jordan_rate_type_code
# jordan_ad_val_rate
# jordan_specific_rate
# jordan_other_rate
# singapore_indicator
# singapore_rate_type_code
# singapore_ad_val_rate
# singapore_specific_rate
# singapore_other_rate
# chile_indicator
# chile_rate_type_code
# chile_ad_val_rate
# chile_specific_rate
# chile_other_rate
# ...

# %%
data.head()
# Out:
#        hts8                                  brief_description  \
# 0  01012100                      Live purebred breeding horses
# 1  01012900    Live horses other than purebred breeding horses
# 2  01013000                                         Live asses
# 3  01019030  Mules and hinnies imported for immediate slaug...
# 4  01019040  Mules and hinnies not imported for immediate s...
#
#   quantity_1_code quantity_2_code wto_binding_code mfn_text_rate  \
# 0              NO             NaN                B          Free
# 1              NO             NaN                B          Free
# 2              NO             NaN                B          6.8%
# 3              NO             NaN                B          Free
# 4              NO             NaN                B          4.5%
#
#   mfn_rate_type_code mfn_ave mfn_ad_val_rate mfn_specific_rate  \
# 0                  0     NaN               0                 0
# 1                  0     NaN               0                 0
# ...
