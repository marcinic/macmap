# %%
import json
import re
import requests
import nltk
import pandas as pd
from bs4 import BeautifulSoup
from xml.etree import ElementTree

# %%
# Full request parameters. Two "all" parameters are allowed per request.
"""
http://wits.worldbank.org/API/V1/SDMX/V21/datasource/TRN/
reporter/{all|reporter code list}
/partner/{all|partner code list}
/product/{ALL|product code list}
/year/{All|Year List
/datatype/{reported|aveestimated}}"""
    
    
    
countries_url = "http://wits.worldbank.org/API/V1/wits/datasource/trn/country/ALL"
nomenclature_url = "http://wits.worldbank.org/API/V1/wits/datasource/trn/nomenclature/" #H0 through H4
products_url = "http://wits.worldbank.org/API/V1/wits/datasource/trn/product/all" # nomenclaturecode is HS

# Country, product, nomenclature, partner list, 
# number preferential agreements, is specific duty expression estimated, last update
data_available_url = "http://wits.worldbank.org/API/V1/wits/datasource/trn/dataavailability/"

# %%
# US 840. Canada 124. EU 918. 710 South Africa
# Make sure partner is taken from Partner list in data availability
test_url = "http://wits.worldbank.org/API/V1/SDMX/V21/datasource/TRN/reporter/918/partner/710/product/ALL/year/2008/datatype/reported"

# %%
res = requests.get(test_url)

# %%
root = ElementTree.fromstring(res.content)
series = root.findall(".//Series")
obs = root.findall(".//Obs")
dataset = root.findall(".//Dataset")

# %%
first = series[0].findall(".//Obs")[0].attrib
attribute = series[0].attrib
combined = {**first,**attribute}
df = pd.DataFrame(columns=list(combined.keys()))

data = [{**s.findall(".//Obs")[0].attrib,**s.attrib}  for s in series]

df = df.append(data)

# %%
df.head()
# Out:
#   PRODUCTCODE      SUM_OF_RATES OBS_VALUE_MEASURE NBR_PREF_LINES  \
# 0      010110  1.20000004768372     SimpleAverage              2
# 1      010190  1.20000004768372     SimpleAverage              3
# 2      010391                 0     SimpleAverage              1
# 3      010392                 0     SimpleAverage              2
# 4      010410                 0     SimpleAverage              2
#
#   NBR_MFN_LINES          MAX_RATE          OBS_VALUE NBR_NA_LINES PARTNER  \
# 0             1  1.20000004768372  0.400000015894572            0     710
# 1             1  1.20000004768372  0.300000011920929            0     710
# 2             1                 0                  0            1     710
# 3             1                 0                  0            2     710
# 4             1                 0                  0            2     710
#
#   NOMENCODE REPORTER MIN_RATE  DATATYPE TARIFFTYPE TIME_PERIOD FREQ  \
# 0        H3      918        0  Reported       PREF        2008    A
# 1        H3      918        0  Reported       PREF        2008    A
# 2        H3      918        0  Reported       PREF        2008    A
# 3        H3      918        0  Reported       PREF        2008    A
# 4        H3      918        0  Reported       PREF        2008    A
#
#   TOTALNOOFLINES
# 0              3
# 1              4
# 2              2
# 3              3
# 4              3

# %%
df.describe()
# Out:
#        PRODUCTCODE SUM_OF_RATES OBS_VALUE_MEASURE NBR_PREF_LINES  \
# count         3562         3562              3562           3562
# unique        3562          104                 1             39
# top         281420            0     SimpleAverage              1
# freq             1         3306              3562           1798
#
#        NBR_MFN_LINES MAX_RATE OBS_VALUE NBR_NA_LINES PARTNER NOMENCODE  \
# count           3562     3562      3562         3562    3562      3562
# unique            25       65       101           27       1         1
# top                0        0         0            0     710        H3
# freq            2983     3306      3306         3363    3562      3562
#
#        REPORTER MIN_RATE  DATATYPE TARIFFTYPE TIME_PERIOD  FREQ TOTALNOOFLINES
# count      3562     3562      3562       3562        3562  3562           3562
# unique        1       44         1          1           1     1             44
# top         918        0  Reported       PREF        2008     A              1
# freq       3562     3349      3562       3562        3562  3562           1561

# %%
df[df.MAX_RATE==df.MIN_RATE].count()
# Out:
# PRODUCTCODE          3489
# SUM_OF_RATES         3489
# OBS_VALUE_MEASURE    3489
# NBR_PREF_LINES       3489
# NBR_MFN_LINES        3489
# MAX_RATE             3489
# OBS_VALUE            3489
# NBR_NA_LINES         3489
# PARTNER              3489
# NOMENCODE            3489
# REPORTER             3489
# MIN_RATE             3489
# DATATYPE             3489
# TARIFFTYPE           3489
# TIME_PERIOD          3489
# FREQ                 3489
# TOTALNOOFLINES       3489
# dtype: int64

# %%
df[df.MAX_RATE=="0"].count()
# Out:
# PRODUCTCODE          3306
# SUM_OF_RATES         3306
# OBS_VALUE_MEASURE    3306
# NBR_PREF_LINES       3306
# NBR_MFN_LINES        3306
# MAX_RATE             3306
# OBS_VALUE            3306
# NBR_NA_LINES         3306
# PARTNER              3306
# NOMENCODE            3306
# REPORTER             3306
# MIN_RATE             3306
# DATATYPE             3306
# TARIFFTYPE           3306
# TIME_PERIOD          3306
# FREQ                 3306
# TOTALNOOFLINES       3306
# dtype: int64

# %%
len(df[df.MAX_RATE==""]) # 96 missing or empty max rates
# Out:
# 96

# %%
df[['NOMENCODE','PRODUCTCODE']]
# Out:
#      NOMENCODE PRODUCTCODE
# 0           H3      010110
# 1           H3      010190
# 2           H3      010391
# 3           H3      010392
# 4           H3      010410
# 5           H3      010420
# 6           H3      010511
# 7           H3      010512
# 8           H3      010519
# 9           H3      010594
# 10          H3      010599
# 11          H3      010619
# 12          H3      010639
# 13          H3      020311
# 14          H3      020312
# 15          H3      020319
# 16          H3      020321
# 17          H3      020322
# 18          H3      020329
# 19          H3      020410
# 20          H3      020421
# 21          H3      020422
# 22          H3      020423
# 23          H3      020430
# 24          H3      020441
# 25          H3      020442
# 26          H3      020443
# 27          H3      020450
# 28          H3      020500
# 29          H3      020680
# ...        ...         ...
# 3532        H3      960719
# 3533        H3      960720
# 3534        H3      960810
# 3535        H3      960820
# 3536        H3      960831
# 3537        H3      960839
# 3538        H3      960840
# 3539        H3      960850
# 3540        H3      960860
# 3541        H3      960891
# 3542        H3      960899
# 3543        H3      960910
# 3544        H3      960920
# 3545        H3      960990
# 3546        H3      961000
# 3547        H3      961100
# 3548        H3      961210
# 3549        H3      961220
# 3550        H3      961310
# 3551        H3      961320
# 3552        H3      961380
# 3553        H3      961390
# 3554        H3      961400
# 3555        H3      961511
# 3556        H3      961519
# 3557        H3      961590
# 3558        H3      961610
# 3559        H3      961620
# 3560        H3      961700
# 3561        H3      961800
#
# [3562 rows x 2 columns]

# %%
# WITS UNCTAD TRAINS provides graphical query interface with API-like url structure
gui_url = "http://wits.worldbank.org/tariff/trains/en/country/USA/year/2014/pagenumber/1/pageSize/134684"
res = requests.get(gui_url)

# %%
soup = BeautifulSoup(res.text,"html.parser")

# %%
scripts = soup.find_all("script")
len(scripts)
# Out:
# 19

# %%
p = re.search("(localdata: \[)(.*)",scripts[7].text)
data = p.group(2)

# %%
fields = ['ProductCode','ProductDescription','Partner','PartnerName','AdValorem','MeasureName','NonAdValorem','AffectedPartners']
rows = [s+"," for s in data.split("},")]


output = []
for row in rows:
    r = {}
    for f in fields:
        s = re.search("(?<="+f+" :)(.*?)(?=,)",row)
        value = s.group(0).replace("\"","")
        #print(f+":"+value)
        r.update({f:value})
    output.append(r)
print(r)
# Out:
# {'PartnerName': ' Non-MFN Countries for USA: 2006  ', 'Partner': ' N76  ', 'ProductDescription': ' Antiques of an age exceeding one hundred years  ', 'AffectedPartners': '   }\r', 'NonAdValorem': '   ', 'ProductCode': ' 97060000  ', 'AdValorem': ' 0.00  ', 'MeasureName': ' Non-MFN duty rate for countries excluded from Most-Favoured- Nation (MFN) treatement  '}

# %%
f = "ProductCode"
s = re.search("(?<="+f+" :)(.*?)(?=,)",rows[0])
value = s.group(0).replace("\"","")
value
# Out:
# ' 01012100  '

# %%
p = re.search('var totalRecords= ([0-9]{1,6})',scripts[7].text)
p.group(0)
# Out:
# 'var totalRecords= 134684'

# %%
dat = pd.DataFrame(output)

# %%
for a in dat.NonAdValorem.unique():
    pass
    #print(a)

# %%
nav_unique = dat.NonAdValorem.unique()
units = """cent_tariff: {<CD><NN>}
           cent_tariff: {<CD><JJ><NN>}
           cent_tariff: {<CD><NNS><DT>}
           dollar_tariff:{<$>?<CD>}
           content:{<IN><DT><NN>}
           content:{<IN><NN><NN>}
           content:{<IN><JJ><NNS>}
           """ # 6.6 cents/kg
percent = "price:{<$>?<CD>}" # $ 1.64/kg
content = "<IN<NN><NN>" #on molybdenum content
extra_feature = "<IN><DT><NN>" # on the case

# value currency_unit weight_unit 
cp = nltk.RegexpParser(units)
for n in nav_unique:
    pos = nltk.pos_tag(nltk.word_tokenize(n))
    print(cp.parse(pos))
# Out:
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# (S )
# (S (cent_tariff 6.6/CD cents/kg/NN))
# (S (cent_tariff 1/CD cents/kg/NN))
# (S (cent_tariff 0.4/CD cents/kg/NN))
# (S (cent_tariff 5.5/CD cents/kg/NN))
# (S (cent_tariff 4.4/CD cents/kg/NN))
# (S $/$ (dollar_tariff 3/head/CD))
# (S (cent_tariff 68/CD cents/head/NN))
# (S (cent_tariff 0.9/CD cents/NNS each/DT))
# (S (cent_tariff 4/CD cents/NNS each/DT))
# (S (cent_tariff 2/CD cents/kg/NN))
# (S (cent_tariff 17.6/CD cents/kg/NN))
# (S (cent_tariff 13.2/CD cents/kg/NN))
# (S (cent_tariff 1.7/CD cents/kg/NN))
# (S (cent_tariff 1.4/CD cents/kg/NN))
# (S (cent_tariff 7.2/CD cents/kg/NN))
# (S (cent_tariff 0.7/CD cents/kg/NN))
# (S (cent_tariff 15.4/CD cents/kg/NN))
# (S (cent_tariff 2.8/CD cents/kg/NN))
# (S (cent_tariff 11/CD cents/kg/NN))
# (S (cent_tariff 8.8/CD cents/kg/NN))
# (S (cent_tariff 22/CD cents/kg/NN))
# (S Not/RB available/JJ)
# (S (cent_tariff 12.3/CD cents/kg/NN))
# (S (cent_tariff 15/CD cents/kg/NN))
# (S (cent_tariff 6/CD cents/kg/NN))
# (S (cent_tariff 6.1/CD cents/kg/NN))
# (S (cent_tariff 0.8/CD cents/kg/NN))
# (S (cent_tariff 7/CD cents/kg/NN))
# (S (cent_tariff 2.2/CD cents/kg/NN))
# (S (cent_tariff 1.1/CD cents/kg/NN))
# (S (cent_tariff 44/CD cents/kg/NN))
# (S (cent_tariff 0.34/CD cents/liter/NN))
# (S (cent_tariff 0.1/CD cents/liter/NN))
# (S (cent_tariff 0.5/CD cents/liter/NN))
# (S (cent_tariff 0.43/CD cents/liter/NN))
# (S (cent_tariff 1.7/CD cents/liter/NN))
# (S (cent_tariff 1.5/CD cents/liter/NN))
# (S (cent_tariff 0.6/CD cents/liter/NN))
# (S (cent_tariff 0.9/CD cents/liter/NN))
# (S (cent_tariff 3.2/CD cents/liter/NN))
# (S (cent_tariff 15/CD cents/liter/NN))
# (S (cent_tariff 1.2/CD cents/liter/NN))
# (S (cent_tariff 77.2/CD cents/liter/NN))
# (S (cent_tariff 7.7/CD cents/liter/NN))
# (S (cent_tariff 15.4/CD cents/liter/NN))
# (S (cent_tariff 56.1/CD cents/liter/NN))
# (S (cent_tariff 54/CD cents/liter/NN))
# (S (cent_tariff 30.9/CD cents/liter/NN))
# (S (cent_tariff 30.8/CD cents/liter/NN))
# (S (dollar_tariff 61.7cents/liter/CD))
# (S (cent_tariff 46.3/CD cents/liter/NN))
# (S (cent_tariff 90.8/CD cents/liter/NN))
# (S (cent_tariff 4.9/CD cents/kg/NN))
# (S (cent_tariff 31/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.646/kg/CD))
# (S (cent_tariff 16.4/CD cents/kg/NN))
# (S (cent_tariff 32.9/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.19/kg/CD))
# (S $/$ (dollar_tariff 1.15/kg/CD))
# (S (cent_tariff 65.9/CD cents/kg/NN))
# (S (cent_tariff 65.8/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.31/kg/CD))
# (S (cent_tariff 98.7/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.936/kg/CD))
# (S (cent_tariff 3.3/CD cents/kg/NN))
# (S (cent_tariff 1.3/CD cents/kg/NN))
# (S (cent_tariff 86.5/CD cents/kg/NN))
# (S (cent_tariff 8.6/CD cents/kg/NN))
# (S (cent_tariff 17.3/CD cents/kg/NN))
# (S (cent_tariff 69.2/CD cents/kg/NN))
# (S (cent_tariff 34.6/CD cents/kg/NN))
# (S (dollar_tariff 69.2cents/kg/CD))
# (S (cent_tariff 55.9/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.018/kg/CD))
# (S (cent_tariff 6.8/CD cents/kg/NN))
# (S (cent_tariff 3.8/CD cents/kg/NN))
# (S (cent_tariff 13.7/CD cents/kg/NN))
# (S (cent_tariff 2.7/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.092/kg/CD))
# (S (cent_tariff 10.9/CD cents/kg/NN))
# (S (cent_tariff 21.8/CD cents/kg/NN))
# (S (cent_tariff 87.3/CD cents/kg/NN))
# (S (cent_tariff 43.7/CD cents/kg/NN))
# (S (cent_tariff 43.6/CD cents/kg/NN))
# (S (dollar_tariff 87.3cents/kg/CD))
# (S (cent_tariff 70.6/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.285/kg/CD))
# (S (cent_tariff 7.8/CD cents/kg/NN))
# (S (cent_tariff 27.3/CD cents/kg/NN))
# (S (cent_tariff 5.4/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.556/kg/CD))
# (S (cent_tariff 15.5/CD cents/kg/NN))
# (S (cent_tariff 31.1/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.24/kg/CD))
# (S $/$ (dollar_tariff 1.08/kg/CD))
# (S (cent_tariff 62.3/CD cents/kg/NN))
# (S (cent_tariff 62.2/CD cents/kg/NN))
# (S (cent_tariff 93.3/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.831/kg/CD))
# (S $/$ (dollar_tariff 1.104/kg/CD) +/NNP (cent_tariff 14.9/CD %/NN))
# (S (cent_tariff 11/CD cents/kg/NN) +/VBD (cent_tariff 1.4/CD %/NN))
# (S (cent_tariff 22/CD cents/kg/NN) +/VBD (cent_tariff 2.9/CD %/NN))
# (S
#   (cent_tariff 88.3/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 11.9/CD %/NN))
# (S
#   (cent_tariff 77.2/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 10.4/CD %/NN))
# (S (cent_tariff 44.2/CD cents/kg/NN) +/VBD (cent_tariff 5.9/CD %/NN))
# (S (cent_tariff 44.1/CD cents/kg/NN) +/VBD (cent_tariff 5.9/CD %/NN))
# (S (dollar_tariff 88.3cents/kg/CD) +/JJ (cent_tariff 11.9/CD %/NN))
# (S (cent_tariff 66.2/CD cents/kg/NN) +/VBD (cent_tariff 8.9/CD %/NN))
# (S $/$ (dollar_tariff 1.299/kg/CD) +/NNP (cent_tariff 17.5/CD %/NN))
# (S (cent_tariff 4/CD cents/kg/NN))
# (S (cent_tariff 5.6/CD cents/kg/NN))
# (S (cent_tariff 31.3/CD cents/kg/NN))
# (S (cent_tariff 3.1/CD cents/kg/NN))
# (S (cent_tariff 6.2/CD cents/kg/NN))
# (S (cent_tariff 25/CD cents/kg/NN))
# (S (cent_tariff 21.9/CD cents/kg/NN))
# (S (cent_tariff 12.5/CD cents/kg/NN))
# (S (cent_tariff 36.8/CD cents/kg/NN))
# (S (cent_tariff 3.9/CD cents/kg/NN))
# (S (cent_tariff 1.5/CD cents/kg/NN))
# (S (cent_tariff 49.6/CD cents/kg/NN))
# (S (cent_tariff 9.9/CD cents/kg/NN))
# (S (cent_tariff 39.6/CD cents/kg/NN))
# (S (cent_tariff 34.7/CD cents/kg/NN))
# (S (cent_tariff 19.8/CD cents/kg/NN))
# (S (cent_tariff 58.4/CD cents/kg/NN))
# (S
#   (cent_tariff 46.3/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 14.9/CD %/NN))
# (S (cent_tariff 4.6/CD cents/kg/NN) +/VBD (cent_tariff 1.4/CD %/NN))
# (S (cent_tariff 9.2/CD cents/kg/NN) +/VBD (cent_tariff 2.9/CD %/NN))
# (S (cent_tariff 37/CD cents/kg/NN) +/VBD (cent_tariff 11.9/CD %/NN))
# (S
#   (cent_tariff 32.4/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 10.4/CD %/NN))
# (S (cent_tariff 18.5/CD cents/kg/NN) +/VBD (cent_tariff 5.9/CD %/NN))
# (S (dollar_tariff 37cents/kg/CD) +/JJ (cent_tariff 11.9/CD %/NN))
# (S (cent_tariff 27.7/CD cents/kg/NN) +/VBD (cent_tariff 8.9/CD %/NN))
# (S
#   (cent_tariff 54.5/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 17.5/CD %/NN))
# (S $/$ (dollar_tariff 1.035/kg/CD) +/NNP (cent_tariff 17/CD %/NN))
# (S (cent_tariff 10.3/CD cents/kg/NN) +/VBD (cent_tariff 1.7/CD %/NN))
# (S (cent_tariff 20.7/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S
#   (cent_tariff 82.8/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 13.6/CD %/NN))
# (S
#   (cent_tariff 72.4/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 11.9/CD %/NN))
# (S (cent_tariff 41.4/CD cents/kg/NN) +/VBD (cent_tariff 6.8/CD %/NN))
# (S (dollar_tariff 82.8cents/kg/CD) +/JJ (cent_tariff 13.6/CD %/NN))
# (S
#   (cent_tariff 62.1/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 10.2/CD %/NN))
# (S $/$ (dollar_tariff 1.217/kg/CD) +/NNP (cent_tariff 20/CD %/NN))
# (S (cent_tariff 87.6/CD cents/kg/NN))
# (S (cent_tariff 8.7/CD cents/kg/NN))
# (S (cent_tariff 17.5/CD cents/kg/NN))
# (S (cent_tariff 70/CD cents/kg/NN))
# (S (cent_tariff 35/CD cents/kg/NN))
# (S (dollar_tariff 70cents/kg/CD))
# (S (cent_tariff 52.5/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.03/kg/CD))
# (S (cent_tariff 30.9/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.034/kg/CD) +/NNP (cent_tariff 17/CD %/NN))
# (S (cent_tariff 20.6/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S
#   (cent_tariff 82.7/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 13.6/CD %/NN))
# (S
#   (cent_tariff 72.3/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 11.9/CD %/NN))
# (S (cent_tariff 41.3/CD cents/kg/NN) +/VBD (cent_tariff 6.8/CD %/NN))
# (S (dollar_tariff 82.7cents/kg/CD) +/JJ (cent_tariff 13.6/CD %/NN))
# (S (cent_tariff 62/CD cents/kg/NN) +/VBD (cent_tariff 10.2/CD %/NN))
# (S $/$ (dollar_tariff 1.035/kg/CD) +/NNP (cent_tariff 8.5/CD %/NN))
# (S (cent_tariff 10.3/CD cents/kg/NN) +/VBD (cent_tariff 0.8/CD %/NN))
# (S (cent_tariff 20.7/CD cents/kg/NN) +/VBD (cent_tariff 1.7/CD %/NN))
# (S (cent_tariff 82.8/CD cents/kg/NN) +/VBD (cent_tariff 6.8/CD %/NN))
# (S (cent_tariff 72.4/CD cents/kg/NN) +/VBD (cent_tariff 5.9/CD %/NN))
# (S (cent_tariff 41.4/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (dollar_tariff 82.8cents/kg/CD) +/JJ (cent_tariff 6.8/CD %/NN))
# (S (cent_tariff 62.1/CD cents/kg/NN) +/VBD (cent_tariff 5.1/CD %/NN))
# (S $/$ (dollar_tariff 1.217/kg/CD) +/NNP (cent_tariff 10/CD %/NN))
# (S (cent_tariff 1.8/CD cents/kg/NN))
# (S (cent_tariff 0.37/CD cents/kg/NN))
# (S (cent_tariff 0.1/CD cents/kg/NN))
# (S (cent_tariff 12/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.189/kg/CD) +/NNP (cent_tariff 8.5/CD %/NN))
# (S (cent_tariff 11.8/CD cents/kg/NN) +/VBD (cent_tariff 0.8/CD %/NN))
# (S (cent_tariff 23.7/CD cents/kg/NN) +/VBD (cent_tariff 1.7/CD %/NN))
# (S (cent_tariff 95.1/CD cents/kg/NN) +/VBD (cent_tariff 6.8/CD %/NN))
# (S (cent_tariff 83.2/CD cents/kg/NN) +/VBD (cent_tariff 5.9/CD %/NN))
# (S (cent_tariff 47.6/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (cent_tariff 47.5/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (dollar_tariff 95.1cents/kg/CD) +/JJ (cent_tariff 6.8/CD %/NN))
# (S (cent_tariff 71.3/CD cents/kg/NN) +/VBD (cent_tariff 5.1/CD %/NN))
# (S $/$ (dollar_tariff 1.399/kg/CD) +/NNP (cent_tariff 10/CD %/NN))
# (S $/$ (dollar_tariff 1.541/kg/CD))
# (S (cent_tariff 30.8/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.12/kg/CD))
# (S $/$ (dollar_tariff 1.07/kg/CD))
# (S (cent_tariff 61.7/CD cents/kg/NN))
# (S (cent_tariff 61.6/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.23/kg/CD))
# (S (cent_tariff 92.4/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.813/kg/CD))
# (S $/$ (dollar_tariff 1.996/kg/CD))
# (S (cent_tariff 19.9/CD cents/kg/NN))
# (S (cent_tariff 39.9/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.45/kg/CD))
# (S $/$ (dollar_tariff 1.39/kg/CD))
# (S (cent_tariff 79.9/CD cents/kg/NN))
# (S (cent_tariff 79.8/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.59/kg/CD))
# (S $/$ (dollar_tariff 2.348/kg/CD))
# (S (cent_tariff 13.1/CD cents/kg/NN))
# (S (cent_tariff 5.7/CD cents/kg/NN))
# (S (cent_tariff 5.2/CD cents/kg/NN))
# (S (cent_tariff 70.4/CD cents/kg/NN) +/VBD (cent_tariff 8.5/CD %/NN))
# (S (cent_tariff 7/CD cents/kg/NN) +/VBD (cent_tariff 0.8/CD %/NN))
# (S (cent_tariff 14/CD cents/kg/NN) +/VBD (cent_tariff 1.7/CD %/NN))
# (S (cent_tariff 56.3/CD cents/kg/NN) +/VBD (cent_tariff 6.8/CD %/NN))
# (S (cent_tariff 49.2/CD cents/kg/NN) +/VBD (cent_tariff 5.9/CD %/NN))
# (S (cent_tariff 28.2/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (cent_tariff 28.1/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (dollar_tariff 56.3cents/kg/CD) +/JJ (cent_tariff 6.8/CD %/NN))
# (S (cent_tariff 42.2/CD cents/kg/NN) +/VBD (cent_tariff 5.1/CD %/NN))
# (S (cent_tariff 82.8/CD cents/kg/NN) +/VBD (cent_tariff 10/CD %/NN))
# (S $/$ (dollar_tariff 1.865/kg/CD) +/NNP (cent_tariff 8.5/CD %/NN))
# (S (cent_tariff 18.6/CD cents/kg/NN) +/VBD (cent_tariff 0.8/CD %/NN))
# (S (cent_tariff 37.3/CD cents/kg/NN) +/VBD (cent_tariff 1.7/CD %/NN))
# (S $/$ (dollar_tariff 1.35/kg/CD) +/NNP (cent_tariff 6.1/CD %/NN))
# (S $/$ (dollar_tariff 1.30/kg/CD) +/NNP (cent_tariff 5.9/CD %/NN))
# (S (cent_tariff 74.7/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (cent_tariff 74.6/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S $/$ (dollar_tariff 1.49/kg/CD) +/NNP (cent_tariff 6.8/CD %/NN))
# (S $/$ (dollar_tariff 1.11/kg/CD) +/NNP (cent_tariff 5.1/CD %/NN))
# (S $/$ (dollar_tariff 2.194/kg/CD) +/NNP (cent_tariff 10/CD %/NN))
# (S $/$ (dollar_tariff 1.509/kg/CD))
# (S (cent_tariff 30.1/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.20/kg/CD))
# (S (cent_tariff 60.4/CD cents/kg/NN))
# (S (cent_tariff 60.3/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.775/kg/CD))
# (S $/$ (dollar_tariff 2.269/kg/CD))
# (S (cent_tariff 22.6/CD cents/kg/NN))
# (S (cent_tariff 45.3/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.81/kg/CD))
# (S (cent_tariff 90.8/CD cents/kg/NN))
# (S (cent_tariff 90.7/CD cents/kg/NN))
# (S $/$ (dollar_tariff 2.67/kg/CD))
# (S $/$ (dollar_tariff 1.227/kg/CD))
# (S (cent_tariff 12.2/CD cents/kg/NN))
# (S (cent_tariff 24.5/CD cents/kg/NN))
# (S (cent_tariff 98.1/CD cents/kg/NN))
# (S (cent_tariff 49.1/CD cents/kg/NN))
# (S (cent_tariff 49/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.22/kg/CD))
# (S $/$ (dollar_tariff 1.443/kg/CD))
# (S $/$ (dollar_tariff 1.055/kg/CD))
# (S (cent_tariff 10.5/CD cents/kg/NN))
# (S (cent_tariff 21.1/CD cents/kg/NN))
# (S (cent_tariff 84.4/CD cents/kg/NN))
# (S (cent_tariff 42.2/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.05/kg/CD))
# (S $/$ (dollar_tariff 1.241/kg/CD))
# (S $/$ (dollar_tariff 1.803/kg/CD))
# (S (cent_tariff 18/CD cents/kg/NN))
# (S (cent_tariff 36/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.44/kg/CD))
# (S (cent_tariff 72.2/CD cents/kg/NN))
# (S (cent_tariff 72.1/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.80/kg/CD))
# (S $/$ (dollar_tariff 2.121/kg/CD))
# (S $/$ (dollar_tariff 2.146/kg/CD))
# (S (cent_tariff 21.4/CD cents/kg/NN))
# (S (cent_tariff 42.9/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.71/kg/CD))
# (S (cent_tariff 85.9/CD cents/kg/NN))
# (S (cent_tariff 85.8/CD cents/kg/NN))
# (S $/$ (dollar_tariff 2.14/kg/CD))
# (S $/$ (dollar_tariff 2.525/kg/CD))
# (S $/$ (dollar_tariff 1.386/kg/CD))
# (S (cent_tariff 13.8/CD cents/kg/NN))
# (S (cent_tariff 27.7/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.10/kg/CD))
# (S (cent_tariff 55.5/CD cents/kg/NN))
# (S (cent_tariff 55.4/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.38/kg/CD))
# (S $/$ (dollar_tariff 1.631/kg/CD))
# (S $/$ (dollar_tariff 1.128/kg/CD))
# (S (cent_tariff 11.2/CD cents/kg/NN))
# (S (cent_tariff 22.5/CD cents/kg/NN))
# (S (cent_tariff 90.2/CD cents/kg/NN))
# (S (cent_tariff 45.1/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.328/kg/CD))
# (S $/$ (dollar_tariff 1.877/kg/CD))
# (S (cent_tariff 18.7/CD cents/kg/NN))
# (S (cent_tariff 37.5/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.50/kg/CD))
# (S (cent_tariff 75.1/CD cents/kg/NN))
# (S (cent_tariff 75/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.87/kg/CD))
# (S $/$ (dollar_tariff 2.208/kg/CD))
# (S (cent_tariff 2.8/CD cents/doz/NN) ./.)
# (S (cent_tariff 10/CD cents/doz/NN) ./.)
# (S (cent_tariff 47.6/CD cents/kg/NN))
# (S (cent_tariff 33.3/CD cents/kg/NN))
# (S (cent_tariff 4.7/CD cents/kg/NN))
# (S (cent_tariff 59.5/CD cents/kg/NN))
# (S (cent_tariff 9.7/CD cents/kg/NN))
# (S (cent_tariff 24.3/CD cents/kg/NN))
# (S (cent_tariff 19/CD cents/kg/NN))
# (S (cent_tariff 6.7/CD cents/kg/NN))
# (S (cent_tariff 1.9/CD cents/kg/NN))
# (S (cent_tariff 89.6/CD cents/1000/NN))
# (S $/$ (dollar_tariff 6/1000/CD))
# (S (cent_tariff 38.4/CD cents/1000/NN))
# (S $/$ (dollar_tariff 4/1000/CD))
# (S (cent_tariff 55.7/CD cents/1000/NN))
# (S $/$ (dollar_tariff 1.34/1000/CD))
# (S (cent_tariff 19.2/CD cents/1000/NN))
# (S $/$ (dollar_tariff 2/1000/CD))
# (S $/$ (dollar_tariff 1.44/1000/CD))
# (S (cent_tariff 0.5/CD cents/kg/NN))
# (S (cent_tariff 0.83/CD cents/kg/NN))
# (S (cent_tariff 0.96/CD cents/kg/NN))
# (S (cent_tariff 2.1/CD cents/kg/NN))
# (S (cent_tariff 0.43/CD cents/kg/NN))
# (S (cent_tariff 0.54/CD cents/kg/NN))
# (S (cent_tariff 3.7/CD cents/kg/NN))
# (S (cent_tariff 0.15/CD cents/kg/NN))
# (S (cent_tariff 0.6/CD cents/kg/NN))
# (S (cent_tariff 4.2/CD cents/kg/NN))
# (S (cent_tariff 2.3/CD cents/kg/NN))
# (S (cent_tariff 7.7/CD cents/kg/NN))
# (S (cent_tariff 2.6/CD cents/kg/NN))
# (S (cent_tariff 0.25/CD cents/kg/NN))
# (S (cent_tariff 8.8/CD cents/kg/NN) +/VBD (cent_tariff 20/CD %/NN))
# (S (cent_tariff 3.8/CD cents/kg/NN) +/VBD (cent_tariff 8.8/CD %/NN))
# (S (cent_tariff 0.8/CD cents/kg/NN) +/VBD (cent_tariff 2/CD %/NN))
# (S (cent_tariff 3.5/CD cents/kg/NN) +/VBD (cent_tariff 8/CD %/NN))
# (S (cent_tariff 3.5/CD cents/kg/NN) +/VBD (cent_tariff 8/CD %/NN))
# (S (cent_tariff 22/CD cents/kg/NN) +/VBD (cent_tariff 45/CD %/NN))
# (S (cent_tariff 3.5/CD cents/kg/NN))
# (S (cent_tariff 5.7/CD cents/kg/NN) +/VBD (cent_tariff 8/CD %/NN))
# (S (cent_tariff 2.2/CD cents/kg/NN) +/VBD (cent_tariff 3.2/CD %/NN))
# (S (cent_tariff 2.9/CD cents/kg/NN))
# (S (cent_tariff 3.7/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 7.4/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 5.9/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 4.1/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 2.3/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (dollar_tariff 4.1cents/kg/CD) on/IN drained/VBN weight/NN)
# (S (cent_tariff 8.6/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 10.8/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S
#   (cent_tariff 5.7/CD cents/kg/NN)
#   on/IN
#   drained/JJ
#   weight/NN
#   +/$
#   (cent_tariff 8/CD %/NN))
# (S
#   (cent_tariff 0.4/CD cents/kg/NN)
#   on/IN
#   drained/JJ
#   weight/NN
#   +/$
#   (cent_tariff 0.6/CD %/NN))
# (S
#   (cent_tariff 2.2/CD cents/kg/NN)
#   on/IN
#   drained/JJ
#   weight/NN
#   +/$
#   (cent_tariff 3.2/CD %/NN))
# (S
#   (cent_tariff 0.5/CD cents/kg/NN)
#   on/IN
#   drained/JJ
#   weight/NN
#   +/$
#   (cent_tariff 0.8/CD %/NN))
# (S
#   (cent_tariff 22/CD cents/kg/NN)
#   on/IN
#   drained/JJ
#   weight/NN
#   +/$
#   (cent_tariff 45/CD %/NN))
# (S (cent_tariff 1.3/CD cents/kg/NN) +/VBD (cent_tariff 1.8/CD %/NN))
# (S (cent_tariff 1.9/CD cents/kg/NN) +/VBD (cent_tariff 2.6/CD %/NN))
# (S (cent_tariff 2.5/CD cents/kg/NN))
# (S (cent_tariff 0.3/CD cents/kg/NN))
# (S (cent_tariff 1.2/CD cents/kg/NN))
# (S (cent_tariff 12.1/CD cents/kg/NN))
# (S (cent_tariff 24/CD cents/kg/NN))
# (S (cent_tariff 40.8/CD cents/kg/NN))
# (S (cent_tariff 14.1/CD cents/kg/NN))
# (S (cent_tariff 26.5/CD cents/kg/NN))
# (S (cent_tariff 33.1/CD cents/kg/NN))
# (S (cent_tariff 0.9/CD cents/kg/NN))
# (S (cent_tariff 5/CD cents/kg/NN))
# (S (cent_tariff 16.5/CD cents/kg/NN))
# (S (cent_tariff 7.9/CD cents/kg/NN))
# (S (cent_tariff 0.51/CD cents/kg/NN))
# (S (cent_tariff 0.64/CD cents/kg/NN))
# (S (cent_tariff 2.11/CD cents/kg/NN))
# (S (cent_tariff 0.44/CD cents/kg/NN))
# (S (cent_tariff 0.2/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.13/m3/CD))
# (S $/$ (dollar_tariff 8.83/m3/CD))
# (S $/$ (dollar_tariff 1.80/m3/CD))
# (S (cent_tariff 0.18/CD cents/kg/NN))
# (S (cent_tariff 13.4/CD cents/kg/NN))
# (S (cent_tariff 5.3/CD cents/kg/NN))
# (S (cent_tariff 20.9/CD cents/kg/NN))
# (S (cent_tariff 0.74/CD cents/kg/NN))
# (S (cent_tariff 10.6/CD cents/kg/NN))
# (S (cent_tariff 1.6/CD cents/kg/NN))
# (S (cent_tariff 3/CD cents/kg/NN))
# (S (cent_tariff 66/CD cents/kg/NN))
# (S (cent_tariff 7.4/CD cents/kg/NN))
# (S (cent_tariff 0.65/CD cents/kg/NN))
# (S (cent_tariff 0.35/CD cents/kg/NN))
# (S (cent_tariff 0.59/CD cents/kg/NN))
# (S (cent_tariff 0.92/CD cents/kg/NN))
# (S (cent_tariff 0.98/CD cents/kg/NN))
# (S (cent_tariff 0.05/CD cents/kg/NN))
# (S (cent_tariff 0.22/CD cents/kg/NN))
# (S (cent_tariff 0.55/CD cents/kg/NN))
# (S (cent_tariff 0.32/CD cents/kg/NN))
# (S (cent_tariff 0.12/CD cents/kg/NN))
# (S (cent_tariff 0.09/CD cents/kg/NN))
# (S (cent_tariff 0.23/CD cents/kg/NN))
# (S (cent_tariff 0.45/CD cents/kg/NN))
# (S (cent_tariff 0.88/CD cents/kg/NN))
# (S (cent_tariff 0.42/CD cents/kg/NN))
# (S (cent_tariff 0.56/CD cents/kg/NN))
# (S (cent_tariff 9.35/CD cents/kg/NN))
# (S (cent_tariff 6.5/CD cents/kg/NN))
# (S (cent_tariff 0.39/CD cents/kg/NN))
# (S (cent_tariff 2.55/CD cents/kg/NN))
# (S (cent_tariff 0.58/CD cents/kg/NN))
# (S (cent_tariff 0.47/CD cents/kg/NN))
# (S (cent_tariff 0.73/CD cents/kg/NN))
# (S (cent_tariff 0.06/CD cents/kg/NN))
# (S (cent_tariff 13/CD cents/kg/NN))
# (S (cent_tariff 9/CD cents/kg/NN))
# (S (cent_tariff 5.9/CD cents/kg/NN))
# (S (cent_tariff 55/CD cents/kg/NN))
# (S (cent_tariff 33/CD cents/kg/NN))
# (S (cent_tariff 0.68/CD cents/kg/NN))
# (S (cent_tariff 53/CD cents/kg/NN))
# (S (cent_tariff 39.7/CD cents/t/NN))
# (S (cent_tariff 88.2/CD cents/t/NN))
# (S $/$ (dollar_tariff 1.24/t/CD))
# (S $/$ (dollar_tariff 2.76/t/CD))
# (S $/$ (dollar_tariff 1.65/t/CD))
# (S $/$ (dollar_tariff 5.51/t/CD))
# (S
#   $/$
#   (dollar_tariff 40/kg/CD)
#   of/IN
#   anhydrous/JJ
#   morphine/NN
#   content/NN)
# (S (cent_tariff 89/CD cents/kg/NN))
# (S $/$ (dollar_tariff 5.29/kg/CD))
# (S $/$ (dollar_tariff 4.95/t/CD))
# (S $/$ (dollar_tariff 22/t/CD))
# (S (cent_tariff 6.6/CD cents/kg/NN) +/VBD (cent_tariff 10/CD %/NN))
# (S (cent_tariff 8/CD cents/kg/NN))
# (S (cent_tariff 1.5/CD cents/kg/NN) +/VBD (cent_tariff 5/CD %/NN))
# (S (cent_tariff 0.6/CD cents/kg/NN) +/VBD (cent_tariff 2/CD %/NN))
# (S (cent_tariff 6.6/CD cents/kg/NN) +/VBD (cent_tariff 20/CD %/NN))
# (S (cent_tariff 1.7/CD cents/kg/NN) +/VBD (cent_tariff 5/CD %/NN))
# (S (cent_tariff 9.5/CD cents/kg/NN))
# (S (cent_tariff 7.5/CD cents/kg/NN))
# (S
#   (cent_tariff 5/CD cents/kg/NN)
#   on/IN
#   contents/NNS
#   and/CC
#   container/NN)
# (S
#   (cent_tariff 17.6/CD cents/kg/NN)
#   on/IN
#   contents/NNS
#   and/CC
#   container/NN)
# (S (cent_tariff 3.4/CD cents/kg/NN))
# (S (cent_tariff 14.3/CD cents/kg/NN))
# (S (cent_tariff 1.7/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (cent_tariff 0.6/CD cents/kg/NN) +/VBD (cent_tariff 1.3/CD %/NN))
# (S (cent_tariff 9.9/CD cents/kg/NN) +/VBD (cent_tariff 20/CD %/NN))
# (S (cent_tariff 9.92/CD cents/kg/NN))
# (S (cent_tariff 6.3/CD cents/kg/NN))
# (S (cent_tariff 34.2/CD cents/kg/NN))
# (S (cent_tariff 23.9/CD cents/kg/NN))
# (S (cent_tariff 13.6/CD cents/kg/NN))
# (S (dollar_tariff 27.3cents/kg/CD))
# (S (cent_tariff 20.5/CD cents/kg/NN))
# (S (cent_tariff 40.2/CD cents/kg/NN))
# (S
#   (cent_tariff 3.6606/CD cents/kg/NN)
#   less/JJR
#   (cent_tariff 0.020668/CD cents/kg/NN)
#   (content for/IN each/DT degree/NN)
#   under/IN
#   (dollar_tariff 100/CD)
#   degrees/NNS
#   and/CC
#   fractions/NNS
#   (content of/IN a/DT degree/NN)
#   in/IN
#   proportion/NN
#   but/CC
#   not/RB
#   less/JJR
#   than/IN
#   (cent_tariff 3.143854/CD cents/kg/NN))
# (S
#   (cent_tariff 6.58170/CD cents/kg/NN)
#   less/JJR
#   (dollar_tariff 0.0622005/CD)
#   cents/NNS
#   /kg/JJ
#   (content for/IN each/DT degree/NN)
#   under/IN
#   (dollar_tariff 100/CD)
#   degrees/NNS
#   and/CC
#   fractions/NNS
#   (content of/IN a/DT degree/NN)
#   in/IN
#   proportion/NN
#   but/CC
#   not/RB
#   less/JJR
#   than/IN
#   (dollar_tariff 5.031562/CD)
#   cents/NNS
#   /kg/JJ)
# (S (cent_tariff 35.74/CD cents/kg/NN))
# (S NA/NN)
# (S (cent_tariff 29.7/CD cents/kg/NN))
# (S (cent_tariff 14.2/CD cents/kg/NN))
# (S (cent_tariff 42.05/CD cents/kg/NN))
# (S
#   (cent_tariff 1.4606/CD cents/kg/NN)
#   less/JJR
#   (cent_tariff 0.020668/CD cents/kg/NN)
#   (content for/IN each/DT degree/NN)
#   under/IN
#   (dollar_tariff 100/CD)
#   degrees/NNS
#   and/CC
#   fractions/NNS
#   (content of/IN a/DT degree/NN)
#   in/IN
#   proportion/NN
#   but/CC
#   not/RB
#   less/JJR
#   than/IN
#   (cent_tariff 0.943854/CD cents/kg/NN))
# (S
#   (cent_tariff 4.3817/CD cents/kg/NN)
#   less/JJR
#   (dollar_tariff 0.0622005/CD)
#   cents/NNS
#   /kg/JJ
#   (content for/IN each/DT degree/NN)
#   under/IN
#   (dollar_tariff 100/CD)
#   degrees/NNS
#   and/CC
#   fractions/NNS
#   (content of/IN a/DT degree/NN)
#   in/IN
#   proportion/NN
#   but/CC
#   not/RB
#   less/JJR
#   than/IN
#   (dollar_tariff 2.831562/CD)
#   cents/NNS
#   /kg/JJ)
# (S (cent_tariff 33.87/CD cents/kg/NN))
# (S (cent_tariff 23.7/CD cents/kg/NN))
# (S (cent_tariff 28.1/CD cents/kg/NN))
# (S (cent_tariff 13.5/CD cents/kg/NN))
# (S (cent_tariff 39.85/CD cents/kg/NN))
# (S (cent_tariff 33.9/CD cents/kg/NN) +/VBD (cent_tariff 5.1/CD %/NN))
# (S (cent_tariff 3.3/CD cents/kg/NN) +/VBD (cent_tariff 0.5/CD %/NN))
# (S (cent_tariff 2.8/CD cents/kg/NN) +/VBD (cent_tariff 0.4/CD %/NN))
# (S (cent_tariff 23.7/CD cents/kg/NN) +/VBD (cent_tariff 3.5/CD %/NN))
# (S (cent_tariff 28.2/CD cents/kg/NN) +/VBD (cent_tariff 4.2/CD %/NN))
# (S (cent_tariff 13.5/CD cents/kg/NN) +/VBD (cent_tariff 2/CD %/NN))
# (S (cent_tariff 39.9/CD cents/kg/NN) +/VBD (cent_tariff 6/CD %/NN))
# (S
#   (cent_tariff 16.9/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS)
#   +/VBP
#   (cent_tariff 5.1/CD %/NN))
# (S
#   (cent_tariff 1.6/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS)
#   +/VBP
#   (cent_tariff 0.5/CD %/NN))
# (S
#   (cent_tariff 1.4/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS)
#   +/VBP
#   (cent_tariff 0.4/CD %/NN))
# (S
#   (cent_tariff 11.8/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS)
#   +/VBP
#   (cent_tariff 3.5/CD %/NN))
# (S
#   (cent_tariff 14/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS)
#   +/VBP
#   (cent_tariff 4.2/CD %/NN))
# (S
#   (cent_tariff 6.7/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS)
#   +/VBP
#   (cent_tariff 2/CD %/NN))
# (S
#   (cent_tariff 19.9/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS)
#   +/VBP
#   (cent_tariff 6/CD %/NN))
# (S
#   (cent_tariff 33.9/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS)
#   +/VBP
#   (cent_tariff 5.1/CD %/NN))
# (S
#   (cent_tariff 3.3/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS)
#   +/VBP
#   (cent_tariff 0.5/CD %/NN))
# (S
#   (cent_tariff 2.8/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS)
#   +/VBP
#   (cent_tariff 0.4/CD %/NN))
# (S
#   (cent_tariff 23.7/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS)
#   +/VBP
#   (cent_tariff 3.5/CD %/NN))
# (S
#   (cent_tariff 28.2/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS)
#   +/VBP
#   (cent_tariff 4.2/CD %/NN))
# (S
#   (cent_tariff 13.5/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS)
#   +/VBP
#   (cent_tariff 2/CD %/NN))
# (S
#   (cent_tariff 39.9/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS)
#   +/VBP
#   (cent_tariff 6/CD %/NN))
# (S
#   (cent_tariff 3.6606/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS))
# (S
#   (cent_tariff 1.4/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS))
# (S
#   (cent_tariff 6.58170/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS))
# (S (cent_tariff 0.35/CD cents/liter/NN))
# (S (cent_tariff 1.8/CD cents/liter/NN))
# (S
#   (cent_tariff 0.01/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS))
# (S
#   (cent_tariff 0.07/CD cents/kg/NN)
#   (content of/IN total/JJ sugars/NNS))
# (S (cent_tariff 40/CD cents/kg/NN) +/VBD (cent_tariff 10.4/CD %/NN))
# (S (cent_tariff 4/CD cents/kg/NN) +/VBD (cent_tariff 1/CD %/NN))
# (S (cent_tariff 8/CD cents/kg/NN) +/VBD (cent_tariff 2/CD %/NN))
# (S (cent_tariff 32/CD cents/kg/NN) +/VBD (cent_tariff 8.3/CD %/NN))
# (S (cent_tariff 28/CD cents/kg/NN) +/VBD (cent_tariff 7.2/CD %/NN))
# (S (cent_tariff 16/CD cents/kg/NN) +/VBD (cent_tariff 4.1/CD %/NN))
# (S (dollar_tariff 32cents/kg/CD) +/JJ (cent_tariff 8.3/CD %/NN))
# (S (cent_tariff 24/CD cents/kg/NN) +/VBD (cent_tariff 6.2/CD %/NN))
# (S
#   (cent_tariff 47.4/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 12.2/CD %/NN))
# (S (cent_tariff 3.3/CD cents/kg/NN) +/VBD (cent_tariff 0.8/CD %/NN))
# (S (cent_tariff 33.2/CD cents/kg/NN) +/VBD (cent_tariff 8.6/CD %/NN))
# (S (cent_tariff 0.52/CD cents/kg/NN))
# (S (cent_tariff 21.7/CD cents/kg/NN))
# (S (cent_tariff 15.1/CD cents/kg/NN))
# (S (cent_tariff 25.5/CD cents/kg/NN))
# (S (cent_tariff 33.6/CD cents/kg/NN))
# (S (cent_tariff 23.5/CD cents/kg/NN))
# (S (cent_tariff 27.9/CD cents/kg/NN))
# (S (cent_tariff 39.5/CD cents/kg/NN))
# (S (cent_tariff 37.2/CD cents/kg/NN) +/VBD (cent_tariff 4.3/CD %/NN))
# (S (cent_tariff 3.7/CD cents/kg/NN) +/VBD (cent_tariff 0.4/CD %/NN))
# (S (cent_tariff 7.4/CD cents/kg/NN) +/VBD (cent_tariff 0.8/CD %/NN))
# (S (cent_tariff 29.7/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (cent_tariff 26/CD cents/kg/NN) +/VBD (cent_tariff 3/CD %/NN))
# (S (cent_tariff 14.9/CD cents/kg/NN) +/VBD (cent_tariff 1.7/CD %/NN))
# (S (cent_tariff 14.8/CD cents/kg/NN) +/VBD (cent_tariff 1.7/CD %/NN))
# (S (dollar_tariff 29.7cents/kg/CD) +/JJ (cent_tariff 3.4/CD %/NN))
# (S (cent_tariff 22.3/CD cents/kg/NN) +/VBD (cent_tariff 2.5/CD %/NN))
# (S (cent_tariff 43.8/CD cents/kg/NN) +/VBD (cent_tariff 5/CD %/NN))
# (S (cent_tariff 52.8/CD cents/kg/NN) +/VBD (cent_tariff 4.3/CD %/NN))
# (S (cent_tariff 5.2/CD cents/kg/NN) +/VBD (cent_tariff 0.4/CD %/NN))
# (S (cent_tariff 10.5/CD cents/kg/NN) +/VBD (cent_tariff 0.8/CD %/NN))
# (S (cent_tariff 42.2/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (cent_tariff 36.9/CD cents/kg/NN) +/VBD (cent_tariff 3/CD %/NN))
# (S (cent_tariff 21.1/CD cents/kg/NN) +/VBD (cent_tariff 1.7/CD %/NN))
# (S (dollar_tariff 42.2cents/kg/CD) +/JJ (cent_tariff 3.4/CD %/NN))
# (S (cent_tariff 31.6/CD cents/kg/NN) +/VBD (cent_tariff 2.5/CD %/NN))
# (S (cent_tariff 62.1/CD cents/kg/NN) +/VBD (cent_tariff 5/CD %/NN))
# (S (cent_tariff 30.5/CD cents/kg/NN) +/VBD (cent_tariff 8.5/CD %/NN))
# (S (cent_tariff 3/CD cents/kg/NN) +/VBD (cent_tariff 0.8/CD %/NN))
# (S (cent_tariff 2.5/CD cents/kg/NN) +/VBD (cent_tariff 0.7/CD %/NN))
# (S (cent_tariff 21.3/CD cents/kg/NN) +/VBD (cent_tariff 5.9/CD %/NN))
# (S (cent_tariff 25.3/CD cents/kg/NN) +/VBD (cent_tariff 7/CD %/NN))
# (S (cent_tariff 12.2/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (cent_tariff 35.9/CD cents/kg/NN) +/VBD (cent_tariff 10/CD %/NN))
# (S (cent_tariff 37.2/CD cents/kg/NN) +/VBD (cent_tariff 8.5/CD %/NN))
# (S (cent_tariff 3.7/CD cents/kg/NN) +/VBD (cent_tariff 0.8/CD %/NN))
# (S (cent_tariff 7.4/CD cents/kg/NN) +/VBD (cent_tariff 1.7/CD %/NN))
# (S (cent_tariff 29.7/CD cents/kg/NN) +/VBD (cent_tariff 6.8/CD %/NN))
# (S (cent_tariff 26/CD cents/kg/NN) +/VBD (cent_tariff 5.9/CD %/NN))
# (S (cent_tariff 14.9/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (cent_tariff 14.8/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (dollar_tariff 29.7cents/kg/CD) +/JJ (cent_tariff 6.8/CD %/NN))
# (S (cent_tariff 22.3/CD cents/kg/NN) +/VBD (cent_tariff 5.1/CD %/NN))
# (S (cent_tariff 43.8/CD cents/kg/NN) +/VBD (cent_tariff 10/CD %/NN))
# (S (cent_tariff 52.8/CD cents/kg/NN) +/VBD (cent_tariff 8.5/CD %/NN))
# (S (cent_tariff 5.2/CD cents/kg/NN) +/VBD (cent_tariff 0.8/CD %/NN))
# (S (cent_tariff 10.5/CD cents/kg/NN) +/VBD (cent_tariff 1.7/CD %/NN))
# (S (cent_tariff 42.2/CD cents/kg/NN) +/VBD (cent_tariff 6.8/CD %/NN))
# (S (cent_tariff 36.9/CD cents/kg/NN) +/VBD (cent_tariff 5.9/CD %/NN))
# (S (cent_tariff 21.1/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (dollar_tariff 42.2cents/kg/CD) +/JJ (cent_tariff 6.8/CD %/NN))
# (S (cent_tariff 31.6/CD cents/kg/NN) +/VBD (cent_tariff 5.1/CD %/NN))
# (S (cent_tariff 62.1/CD cents/kg/NN) +/VBD (cent_tariff 10/CD %/NN))
# (S (cent_tariff 3.1/CD cents/kg/NN) +/VBD (cent_tariff 0.7/CD %/NN))
# (S (cent_tariff 30.9/CD cents/kg/NN) +/VBD (cent_tariff 7/CD %/NN))
# (S (dollar_tariff 26cents/kg/CD) +/JJ (cent_tariff 3/CD %/NN))
# (S (cent_tariff 37.2/CD cents/kg/NN) +/VBD (cent_tariff 6/CD %/NN))
# (S (cent_tariff 3.7/CD cents/kg/NN) +/VBD (cent_tariff 0.6/CD %/NN))
# (S (cent_tariff 7.4/CD cents/kg/NN) +/VBD (cent_tariff 1.2/CD %/NN))
# (S (cent_tariff 29.7/CD cents/kg/NN) +/VBD (cent_tariff 4.8/CD %/NN))
# (S (cent_tariff 26/CD cents/kg/NN) +/VBD (cent_tariff 4.2/CD %/NN))
# (S (cent_tariff 14.9/CD cents/kg/NN) +/VBD (cent_tariff 2.4/CD %/NN))
# (S (cent_tariff 14.8/CD cents/kg/NN) +/VBD (cent_tariff 2.4/CD %/NN))
# (S (dollar_tariff 26cents/kg/CD) +/JJ (cent_tariff 4.2/CD %/NN))
# (S (cent_tariff 22.3/CD cents/kg/NN) +/VBD (cent_tariff 3.6/CD %/NN))
# (S (cent_tariff 43.8/CD cents/kg/NN) +/VBD (cent_tariff 7/CD %/NN))
# (S (cent_tariff 52.8/CD cents/kg/NN) +/VBD (cent_tariff 6/CD %/NN))
# (S (cent_tariff 5.2/CD cents/kg/NN) +/VBD (cent_tariff 0.6/CD %/NN))
# (S (cent_tariff 10.5/CD cents/kg/NN) +/VBD (cent_tariff 1.2/CD %/NN))
# (S (cent_tariff 42.2/CD cents/kg/NN) +/VBD (cent_tariff 4.8/CD %/NN))
# (S (cent_tariff 36.9/CD cents/kg/NN) +/VBD (cent_tariff 4.2/CD %/NN))
# (S (cent_tariff 21.1/CD cents/kg/NN) +/VBD (cent_tariff 2.4/CD %/NN))
# (S (dollar_tariff 42.2cents/kg/CD) +/JJ (cent_tariff 4.8/CD %/NN))
# (S (cent_tariff 31.6/CD cents/kg/NN) +/VBD (cent_tariff 3.6/CD %/NN))
# (S (cent_tariff 62.1/CD cents/kg/NN) +/VBD (cent_tariff 7/CD %/NN))
# (S (dollar_tariff 29.7cents/kg/CD) +/JJ (cent_tariff 4.8/CD %/NN))
# (S (cent_tariff 3.1/CD cents/kg/NN) +/VBD (cent_tariff 0.5/CD %/NN))
# (S (cent_tariff 30.9/CD cents/kg/NN) +/VBD (cent_tariff 4.9/CD %/NN))
# (S $/$ (dollar_tariff 1.035/kg/CD) +/NNP (cent_tariff 14.9/CD %/NN))
# (S (cent_tariff 10.3/CD cents/kg/NN) +/VBD (cent_tariff 1.4/CD %/NN))
# (S (cent_tariff 20.7/CD cents/kg/NN) +/VBD (cent_tariff 2.9/CD %/NN))
# (S
#   (cent_tariff 82.8/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 11.9/CD %/NN))
# (S
#   (cent_tariff 72.4/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 10.4/CD %/NN))
# (S (cent_tariff 41.4/CD cents/kg/NN) +/VBD (cent_tariff 5.9/CD %/NN))
# (S (dollar_tariff 82.8cents/kg/CD) +/JJ (cent_tariff 11.9/CD %/NN))
# (S (cent_tariff 62.1/CD cents/kg/NN) +/VBD (cent_tariff 8.9/CD %/NN))
# (S $/$ (dollar_tariff 1.217/kg/CD) +/NNP (cent_tariff 17.5/CD %/NN))
# (S (cent_tariff 42.3/CD cents/kg/NN) +/VBD (cent_tariff 8.5/CD %/NN))
# (S (cent_tariff 4.2/CD cents/kg/NN) +/VBD (cent_tariff 0.8/CD %/NN))
# (S (cent_tariff 8.4/CD cents/kg/NN) +/VBD (cent_tariff 1.7/CD %/NN))
# (S (cent_tariff 33.8/CD cents/kg/NN) +/VBD (cent_tariff 6.8/CD %/NN))
# (S (cent_tariff 29.6/CD cents/kg/NN) +/VBD (cent_tariff 5.9/CD %/NN))
# (S (cent_tariff 16.9/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (dollar_tariff 33.8cents/kg/CD) +/JJ (cent_tariff 6.8/CD %/NN))
# (S (cent_tariff 25.3/CD cents/kg/NN) +/VBD (cent_tariff 5.1/CD %/NN))
# (S (cent_tariff 49.8/CD cents/kg/NN) +/VBD (cent_tariff 10/CD %/NN))
# (S (cent_tariff 3.5/CD cents/kg/NN) +/VBD (cent_tariff 0.7/CD %/NN))
# (S (cent_tariff 35.1/CD cents/kg/NN) +/VBD (cent_tariff 7/CD %/NN))
# (S (cent_tariff 26/CD cents/liter/NN))
# (S $/$ (dollar_tariff 1.035/kg/CD) +/NNP (cent_tariff 13.6/CD %/NN))
# (S (cent_tariff 10.3/CD cents/kg/NN) +/VBD (cent_tariff 1.3/CD %/NN))
# (S (cent_tariff 20.7/CD cents/kg/NN) +/VBD (cent_tariff 2.7/CD %/NN))
# (S
#   (cent_tariff 82.8/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 10.8/CD %/NN))
# (S (cent_tariff 72.4/CD cents/kg/NN) +/VBD (cent_tariff 9.5/CD %/NN))
# (S (cent_tariff 41.4/CD cents/kg/NN) +/VBD (cent_tariff 5.4/CD %/NN))
# (S (dollar_tariff 82.8cents/kg/CD) +/JJ (cent_tariff 10.8/CD %/NN))
# (S (cent_tariff 62.1/CD cents/kg/NN) +/VBD (cent_tariff 8.1/CD %/NN))
# (S $/$ (dollar_tariff 1.217/kg/CD) +/NNP (cent_tariff 16/CD %/NN))
# (S (cent_tariff 23.7/CD cents/kg/NN) +/VBD (cent_tariff 8.5/CD %/NN))
# (S (cent_tariff 2.3/CD cents/kg/NN) +/VBD (cent_tariff 0.8/CD %/NN))
# (S (cent_tariff 1.9/CD cents/kg/NN) +/VBD (cent_tariff 0.7/CD %/NN))
# (S (cent_tariff 16.5/CD cents/kg/NN) +/VBD (cent_tariff 5.9/CD %/NN))
# (S (cent_tariff 19.7/CD cents/kg/NN) +/VBD (cent_tariff 7/CD %/NN))
# (S (cent_tariff 9.4/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (cent_tariff 27.9/CD cents/kg/NN) +/VBD (cent_tariff 10/CD %/NN))
# (S
#   (cent_tariff 6/CD cents/kg/NN)
#   drained/VBD
#   weight/JJ
#   +/RB
#   (cent_tariff 8.5/CD %/NN))
# (S
#   (cent_tariff 0.4/CD cents/kg/NN)
#   on/IN
#   drained/JJ
#   weight/NN
#   +/$
#   (cent_tariff 0.7/CD %/NN))
# (S
#   (cent_tariff 2.1/CD cents/kg/NN)
#   (content on/IN entire/JJ contents/NNS)
#   of/IN
#   container/NN)
# (S
#   (cent_tariff 6.6/CD cents/kg/NN)
#   (content on/IN entire/JJ contents/NNS)
#   of/IN
#   container/NN)
# (S
#   (cent_tariff 4.4/CD cents/kg/NN)
#   (content on/IN entire/JJ contents/NNS)
#   of/IN
#   container/NN)
# (S
#   (cent_tariff 1.5/CD cents/kg/NN)
#   (content on/IN entire/JJ contents/NNS)
#   of/IN
#   container/NN)
# (S (cent_tariff 5.4/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 2.1/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 2.5/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (dollar_tariff 1.4cents/kg/CD) on/IN drained/VBN weight/NN)
# (S (cent_tariff 6.9/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 4.8/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (dollar_tariff 2.7cents/kg/CD) on/IN drained/VBN weight/NN)
# (S (cent_tariff 9.3/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 11.6/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 10.1/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 4/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 11.9/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 9.9/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 4.3/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 10/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 5.5/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 11/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 8.8/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (cent_tariff 6.1/CD cents/kg/NN) on/IN drained/JJ weight/NN)
# (S (dollar_tariff 3.5cents/kg/CD) on/IN drained/VBN weight/NN)
# (S
#   (cent_tariff 0.8/CD cents/kg/NN)
#   (content on/IN entire/JJ contents/NNS)
#   of/IN
#   container/NN)
# (S (cent_tariff 9.9/CD cents/kg/NN) +/VBD (cent_tariff 6.4/CD %/NN))
# (S (cent_tariff 0.8/CD cents/kg/NN) +/VBD (cent_tariff 0.5/CD %/NN))
# (S (cent_tariff 5.6/CD cents/kg/NN) +/VBD (cent_tariff 3.6/CD %/NN))
# (S (cent_tariff 2.4/CD cents/kg/NN) +/VBD (cent_tariff 1.6/CD %/NN))
# (S (cent_tariff 20.9/CD cents/kg/NN) +/VBD (cent_tariff 40/CD %/NN))
# (S (cent_tariff 10/CD cents/kg/NN))
# (S (cent_tariff 11.3/CD cents/kg/NN))
# (S (cent_tariff 32.6/CD cents/kg/NN))
# (S (cent_tariff 3.2/CD cents/kg/NN))
# (S (cent_tariff 6.4/CD cents/kg/NN))
# (S (cent_tariff 0.28/CD cents/kg/NN))
# (S (cent_tariff 6.9/CD cents/kg/NN) +/VBD (cent_tariff 4.5/CD %/NN))
# (S (cent_tariff 2.7/CD cents/kg/NN) +/VBD (cent_tariff 1.8/CD %/NN))
# (S (cent_tariff 21/CD cents/kg/NN) +/VBD (cent_tariff 40/CD %/NN))
# (S (cent_tariff 7.85/CD cents/liter/NN))
# (S (cent_tariff 3.4/CD cents/liter/NN))
# (S (cent_tariff 0.7/CD cents/liter/NN))
# (S (cent_tariff 1.3/CD cents/liter/NN))
# (S (cent_tariff 3.1/CD cents/liter/NN))
# (S (cent_tariff 18/CD cents/liter/NN))
# (S (cent_tariff 4.5/CD cents/liter/NN))
# (S (cent_tariff 1.9/CD cents/liter/NN))
# (S (cent_tariff 0.3/CD cents/liter/NN))
# (S (cent_tariff 1.8/CD cents/liter/NN) (/( KR/NNP)
# (S (cent_tariff 4.5/CD cents//NN) liter/NN)
# (S (cent_tariff 7.9/CD cents/liter/NN))
# (S (cent_tariff 3.1/CD cents/liter/NN) (/( KR/NNP)
# (S (cent_tariff 4.2/CD cents/liter/NN))
# (S (cent_tariff 1.6/CD cents/liter/NN))
# (S (cent_tariff 0.4/CD cents/liter/NN))
# (S (cent_tariff 1/CD cents/liter/NN))
# (S (cent_tariff 0.14/CD cents/liter/NN))
# (S (cent_tariff 4/CD cents/liter/NN))
# (S (cent_tariff 4.4/CD cents/liter/NN))
# (S (cent_tariff 0.64/CD cents/liter/NN))
# (S (cent_tariff 0.2/CD cents/liter/NN))
# (S (cent_tariff 7.4/CD cents/liter/NN))
# (S (cent_tariff 2.9/CD cents/liter/NN))
# (S (cent_tariff 30.5/CD cents/kg/NN) +/VBD (cent_tariff 6.4/CD %/NN))
# (S (cent_tariff 3/CD cents/kg/NN) +/VBD (cent_tariff 0.6/CD %/NN))
# (S (cent_tariff 2.5/CD cents/kg/NN) +/VBD (cent_tariff 0.5/CD %/NN))
# (S (cent_tariff 21.3/CD cents/kg/NN) +/VBD (cent_tariff 4.4/CD %/NN))
# (S (cent_tariff 25.3/CD cents/kg/NN) +/VBD (cent_tariff 5.3/CD %/NN))
# (S (cent_tariff 12.2/CD cents/kg/NN) +/VBD (cent_tariff 2.5/CD %/NN))
# (S (cent_tariff 35.9/CD cents/kg/NN) +/VBD (cent_tariff 7.5/CD %/NN))
# (S (cent_tariff 50.2/CD cents/kg/NN) +/VBD (cent_tariff 17/CD %/NN))
# (S (cent_tariff 5/CD cents/kg/NN) +/VBD (cent_tariff 1.7/CD %/NN))
# (S (cent_tariff 10/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S
#   (cent_tariff 36.5/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 12.3/CD %/NN))
# (S
#   (cent_tariff 35.1/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 11.9/CD %/NN))
# (S (cent_tariff 20.1/CD cents/kg/NN) +/VBD (cent_tariff 6.8/CD %/NN))
# (S (cent_tariff 20/CD cents/kg/NN) +/VBD (cent_tariff 6.8/CD %/NN))
# (S
#   (cent_tariff 30.1/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 10.2/CD %/NN))
# (S (cent_tariff 59/CD cents/kg/NN) +/VBD (cent_tariff 20/CD %/NN))
# (S
#   (cent_tariff 40.1/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 13.6/CD %/NN))
# (S (dollar_tariff 40.1cents/kg/CD) +/JJ (cent_tariff 13.6/CD %/NN))
# (S (cent_tariff 86.2/CD cents/kg/NN))
# (S (cent_tariff 17.2/CD cents/kg/NN))
# (S (cent_tariff 68.9/CD cents/kg/NN))
# (S (cent_tariff 34.5/CD cents/kg/NN))
# (S (cent_tariff 34.4/CD cents/kg/NN))
# (S (dollar_tariff 68.9cents/kg/CD))
# (S (cent_tariff 80.4/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.014/kg/CD))
# (S (cent_tariff 4.2/CD cents/kg/NN) +/VBD (cent_tariff 1.9/CD %/NN))
# (S (cent_tariff 44/CD cents/kg/NN) +/VBD (cent_tariff 25/CD %/NN))
# (S (cent_tariff 8.4/CD cents/kg/NN) +/VBD (cent_tariff 1.9/CD %/NN))
# (S (cent_tariff 5.8/CD cents/kg/NN) +/VBD (cent_tariff 1.3/CD %/NN))
# (S (cent_tariff 88/CD cents/kg/NN) +/VBD (cent_tariff 25/CD %/NN))
# (S (cent_tariff 17/CD cents/kg/NN) +/VBD (cent_tariff 1.9/CD %/NN))
# (S (cent_tariff 6.8/CD cents/kg/NN) +/VBD (cent_tariff 0.7/CD %/NN))
# (S $/$ (dollar_tariff 1.76/kg/CD) +/NNP (cent_tariff 25/CD %/NN))
# (S (cent_tariff 10.7/CD cents/kg/NN))
# (S
#   The/DT
#   rate/NN
#   applicable/JJ
#   to/TO
#   the/DT
#   natural/JJ
#   juice/NN
#   in/IN
#   heading/VBG
#   (dollar_tariff 2009/CD))
# (S (cent_tariff 5.8/CD cents/kg/NN) +/VBD (cent_tariff 0.7/CD %/NN))
# (S (cent_tariff 58.5/CD cents/kg/NN) +/VBD (cent_tariff 7/CD %/NN))
# (S (cent_tariff 28.8/CD cents/kg/NN) +/VBD (cent_tariff 8.5/CD %/NN))
# (S (cent_tariff 2.8/CD cents/kg/NN) +/VBD (cent_tariff 0.8/CD %/NN))
# (S (cent_tariff 5.7/CD cents/kg/NN) +/VBD (cent_tariff 1.7/CD %/NN))
# (S (cent_tariff 23/CD cents/kg/NN) +/VBD (cent_tariff 6.8/CD %/NN))
# (S (cent_tariff 20.1/CD cents/kg/NN) +/VBD (cent_tariff 5.9/CD %/NN))
# (S (cent_tariff 11.5/CD cents/kg/NN) +/VBD (cent_tariff 3.4/CD %/NN))
# (S (dollar_tariff 23cents/kg/CD) +/JJ (cent_tariff 6.8/CD %/NN))
# (S (cent_tariff 17.2/CD cents/kg/NN) +/VBD (cent_tariff 5.1/CD %/NN))
# (S (cent_tariff 33.9/CD cents/kg/NN) +/VBD (cent_tariff 10/CD %/NN))
# (S (cent_tariff 2.4/CD cents/kg/NN) +/VBD (cent_tariff 0.7/CD %/NN))
# (S (cent_tariff 23.9/CD cents/kg/NN) +/VBD (cent_tariff 7/CD %/NN))
# (S (cent_tariff 0.26/CD cents/liter/NN))
# (S (cent_tariff 2.6/CD cents/liter/NN))
# (S
#   (cent_tariff 23.5/CD cents/liter/NN)
#   +/VBD
#   (cent_tariff 14.9/CD %/NN))
# (S
#   (cent_tariff 2.3/CD cents/liter/NN)
#   +/VBD
#   (cent_tariff 1.4/CD %/NN))
# (S
#   (cent_tariff 4.7/CD cents/liter/NN)
#   +/VBD
#   (cent_tariff 2.9/CD %/NN))
# (S
#   (cent_tariff 18.8/CD cents/kg/NN)
#   +/VBD
#   (cent_tariff 11.9/CD %/NN))
# (S
#   (cent_tariff 16.4/CD cents/liter/NN)
#   +/VBD
#   (cent_tariff 10.4/CD %/NN))
# (S
#   (cent_tariff 9.4/CD cents/liter/NN)
#   +/VBD
#   (cent_tariff 5.9/CD %/NN))
# (S (dollar_tariff 16.4cents/kg/CD) (cent_tariff +10.4/CD %/NN))
# (S
#   (cent_tariff 14.1/CD cents/liter/NN)
#   +/VBD
#   (cent_tariff 8.9/CD %/NN))
# (S
#   (cent_tariff 27.6/CD cents/liter/NN)
#   +/VBD
#   (cent_tariff 17.5/CD %/NN))
# (S (cent_tariff 13.2/CD cents/liter/NN))
# (S (cent_tariff 19.8/CD cents/liter/NN))
# (S (cent_tariff 7.1/CD cents/liter/NN))
# (S (dollar_tariff 8.8cents/liter/CD))
# (S $/$ (dollar_tariff 1.59/liter/CD))
# (S (cent_tariff 12.6/CD cents/liter/NN))
# (S (cent_tariff 6.3/CD cents/liter/NN))
# (S (cent_tariff 2.2/CD cents/liter/NN))
# (S (dollar_tariff 2.8cents/liter/CD))
# (S (cent_tariff 33/CD cents/liter/NN))
# (S (cent_tariff 5.3/CD cents/liter/NN))
# (S (dollar_tariff 2.3cents/liter/CD))
# (S (cent_tariff 16.9/CD cents/liter/NN))
# (S (cent_tariff 6/CD cents/liter/NN))
# (S (dollar_tariff 7.5cents/liter/CD))
# (S (cent_tariff 8.4/CD cents/liter/NN))
# (S (dollar_tariff 3.7cents/liter/CD))
# (S (cent_tariff 5.6/CD cents/liter/NN))
# (S (cent_tariff 22.4/CD cents/liter/NN))
# (S (cent_tariff 13/CD cents/liter/NN))
# (S (dollar_tariff 9.9cents/liter/CD))
# (S (cent_tariff 14/CD cents/liter/NN))
# (S (cent_tariff 1.4/CD cents/liter/NN))
# (S (dollar_tariff 6.2cents/liter/CD))
# (S (cent_tariff 8/CD cents/liter/NN))
# (S (cent_tariff 2.3/CD cents/liter/NN))
# (S (cent_tariff 12.8/CD cents/liter/NN))
# (S (cent_tariff 4.1/CD cents/liter/NN))
# (S
#   (cent_tariff 4.4/CD cents/liter/NN)
#   +/VBD
#   (cent_tariff 31.4/CD cents/pf/NN)
#   ./.
#   liter/NN)
# (S
#   (cent_tariff 2.9/CD cents/liter/NN)
#   +/VBD
#   (cent_tariff 20.9/CD cents/pf/NN)
#   ./.
#   liter/NN)
# (S
#   (dollar_tariff 1.9cents/liter/CD)
#   +/JJ
#   (cent_tariff 13.9/CD cents/pf/NN)
#   ./.
#   liter/NN)
# (S
#   (cent_tariff 18.5/CD cents/liter/NN)
#   +/VBD
#   $/$
#   (dollar_tariff 1.32/pf/CD)
#   ./.
#   liter/NN
#   (dollar_tariff 1//CD))
# (S (cent_tariff 3.5/CD cents/liter/NN))
# (S (dollar_tariff 1.5cents/liter/CD))
# (S (cent_tariff 33/CD cents//NN) liter/NN)
# (S (dollar_tariff 1.8cents/liter/CD))
# (S (cent_tariff 3.8/CD cents/liter/NN))
# (S (dollar_tariff 1.6cents/liter/CD))
# (S (dollar_tariff 0.1cents/liter/CD))
# (S
#   (cent_tariff 3.1/CD cents/liter/NN)
#   +/VBD
#   (cent_tariff 22.1/CD cents/pf/NN)
#   ./.
#   liter/NN
#   on/IN
#   ethyl/JJ
#   alcohol/NN
#   content/NN)
# (S
#   (dollar_tariff 18.5/CD)
#   cents//JJ
#   liter/JJR
#   +/JJ
#   $/$
#   (dollar_tariff 1.32/pf/CD)
#   ./.
#   liter/NN
#   on/IN
#   ethyl/JJ
#   alcohol/NN
#   content/NN)
# (S (cent_tariff 3/CD cents/liter/NN))
# (S (dollar_tariff 1.3cents/liter/CD))
# (S (cent_tariff 13.9/CD cents/liter/NN))
# (S (dollar_tariff 6.1cents/liter/CD))
# (S (cent_tariff 5.5/CD cents/liter/NN))
# (S (cent_tariff 18.9/CD cents/pf.liter/NN))
# (S $/$ (dollar_tariff 1.32/pf/CD) ./. liter/NN)
# (S $/$ (dollar_tariff 1.78/pf/CD) ./. liter/NN)
# (S $/$ (dollar_tariff 2.35/pf/CD) ./. liter/NN)
# (S $/$ (dollar_tariff 1.99/pf/CD) ./. liter/NN)
# (S $/$ (dollar_tariff 2.04/pf/CD) ./. liter/NN)
# (S (cent_tariff 23.7/CD cents/pf.liter/NN))
# (S $/$ (dollar_tariff 3.08/pf/CD) ./. liter/NN)
# (S $/$ (dollar_tariff 1.68/pf/CD) ./. liter/NN)
# (S (cent_tariff 21.1/CD cents/pf.liter/NN))
# (S $/$ (dollar_tariff 4.05/pf/CD) ./. liter/NN)
# (S (cent_tariff 0.5/CD cents/pf.liter/NN))
# (S (cent_tariff 2.1/CD cents/pf.liter/NN))
# (S $/$ (dollar_tariff 4.91/t/CD))
# (S (cent_tariff 0.17/CD cents/kg/NN))
# (S (cent_tariff 80.4/CD cents/kg/NN) +/VBD (cent_tariff 6.4/CD %/NN))
# (S (cent_tariff 8/CD cents/kg/NN) +/VBD (cent_tariff 0.6/CD %/NN))
# (S (cent_tariff 16/CD cents/kg/NN) +/VBD (cent_tariff 1.2/CD %/NN))
# (S (cent_tariff 64.3/CD cents/kg/NN) +/VBD (cent_tariff 5.1/CD %/NN))
# (S (cent_tariff 56.2/CD cents/kg/NN) +/VBD (cent_tariff 4.4/CD %/NN))
# (S (cent_tariff 32.2/CD cents/kg/NN) +/VBD (cent_tariff 2.5/CD %/NN))
# (S (cent_tariff 32.1/CD cents/kg/NN) +/VBD (cent_tariff 2.5/CD %/NN))
# (S (dollar_tariff 64.3cents/kg/CD) +/JJ (cent_tariff 5.1/CD %/NN))
# (S (cent_tariff 48.2/CD cents/kg/NN) +/VBD (cent_tariff 3.8/CD %/NN))
# (S (cent_tariff 94.6/CD cents/kg/NN) +/VBD (cent_tariff 7.5/CD %/NN))
# (S (dollar_tariff 56.2cents/kg/CD) +/JJ (cent_tariff 4.4/CD %/NN))
# (S $/$ (dollar_tariff 5.02/kg/CD))
# (S (cent_tariff 77.2/CD cents/kg/NN))
# (S (cent_tariff 85/CD cents/kg/NN))
# (S (cent_tariff 16.7/CD cents/kg/NN))
# (S (cent_tariff 32.7/CD cents/kg/NN))
# (S (cent_tariff 22.8/CD cents/kg/NN))
# (S $/$ (dollar_tariff 5.48/kg/CD))
# (S (cent_tariff 54.8/CD cents/kg/NN))
# (S $/$ (dollar_tariff 6.45/kg/CD))
# (S $/$ (dollar_tariff 1.21/kg/CD))
# (S (cent_tariff 40.9/CD cents/kg/NN))
# (S (cent_tariff 23.3/CD cents/kg/NN))
# (S (cent_tariff 28.6/CD cents/kg/NN))
# (S (cent_tariff 39.7/CD cents/kg/NN))
# (S (cent_tariff 17.4/CD cents/kg/NN))
# (S (cent_tariff 26.2/CD cents/kg/NN))
# (S (cent_tariff 97/CD cents/kg/NN))
# (S (cent_tariff 28.4/CD cents/kg/NN))
# (S (cent_tariff 12.4/CD cents/kg/NN))
# (S (cent_tariff 16.2/CD cents/kg/NN))
# (S (cent_tariff 67.9/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.89/kg/CD) +/NNP (cent_tariff 4.7/CD %/NN))
# (S $/$ (dollar_tariff 1.08/kg/CD) +/NNP (cent_tariff 2.6/CD %/NN))
# (S $/$ (dollar_tariff 9.92/kg/CD) +/NNP (cent_tariff 25/CD %/NN))
# (S (cent_tariff 57/CD cents/kg/NN) +/VBD (cent_tariff 1.4/CD %/NN))
# (S (cent_tariff 41.7/CD cents/kg/NN) +/VBD (cent_tariff 0.9/CD %/NN))
# (S $/$ (dollar_tariff 1.05/kg/CD) +/NNP (cent_tariff 2.3/CD %/NN))
# (S (cent_tariff 60/CD cents/kg/NN) +/VBD (cent_tariff 1.3/CD %/NN))
# (S (cent_tariff 10.5/CD cents/kg/NN) +/VBD (cent_tariff 0.2/CD %/NN))
# (S $/$ (dollar_tariff 1.50/kg/CD) +/NNP (cent_tariff 3.2/CD %/NN))
# (S (cent_tariff 60/CD cents/kg/NN) +/VBD (cent_tariff 1.2/CD %/NN))
# (S (cent_tariff 32.8/CD cents/kg/NN))
# (S (cent_tariff 22.9/CD cents/kg/NN))
# (S (cent_tariff 62/CD cents/kg/NN))
# (S (cent_tariff 35.4/CD cents/kg/NN))
# (S (cent_tariff 13.9/CD cents/kg/NN))
# (S (cent_tariff 24.7/CD cents/kg/NN))
# (S (cent_tariff 3.6/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.97/t/CD))
# (S $/$ (dollar_tariff 2.46/t/CD))
# (S $/$ (dollar_tariff 3.20/t/CD))
# (S $/$ (dollar_tariff 7.38/t/CD))
# (S $/$ (dollar_tariff 1.25/t/CD))
# (S $/$ (dollar_tariff 3.94/t/CD))
# (S $/$ (dollar_tariff 22.95/m3/CD))
# (S $/$ (dollar_tariff 5.30/m3/CD))
# (S $/$ (dollar_tariff 1.10/t/CD))
# (S $/$ (dollar_tariff 10.33/t/CD))
# (S $/$ (dollar_tariff 20.70/t/CD))
# (S $/$ (dollar_tariff 1.38/t/CD))
# (S (cent_tariff 0.2/CD cents/kg/NN))
# (S (cent_tariff 0.3/CD cents/kg/NN))
# (S $/$ (dollar_tariff 1.32/t/CD))
# (S $/$ (dollar_tariff 1.76/t/CD))
# (S (cent_tariff 49/CD cents/t/NN))
# (S (cent_tariff 2.2/CD cents/kg/NN) on/IN manganese/JJ content/NN)
# (S
#   (cent_tariff 1.7/CD cents/kg/NN)
#   (content on/IN lead/NN content/NN))
# (S
#   (cent_tariff 8.8/CD cents/kg/NN)
#   (content on/IN copper/NN content/NN)
#   +/VBD
#   (cent_tariff 3.3/CD cents/kg/NN)
#   (content on/IN lead/NN content/NN)
#   +/VBD
#   (cent_tariff 3.7/CD cents/kg/NN)
#   (content on/IN zinc/NN content/NN))
# (S $/$ (dollar_tariff 1/t/CD))
# (S
#   (cent_tariff 1.1/CD cents/kg/NN)
#   (content on/IN lead/NN content/NN))
# (S $/$ (dollar_tariff 1.10/kg/CD) on/IN tungsten/NNS content/JJ)
# (S
#   (cent_tariff 37.5/CD cents/kg/NN)
#   (content on/IN tungsten/NN content/NN))
# (S
#   (cent_tariff 12.8/CD cents/kg/NN)
#   (content on/IN molybdenum/NN content/NN)
#   +/VBD
#   (cent_tariff 1.8/CD %/NN))
# (S
#   $/$
#   (dollar_tariff 1.10/kg/CD)
#   (content on/IN molybdenum/NN content/NN)
#   +/VBD
#   (cent_tariff 15/CD %/NN))
# (S
#   (cent_tariff 17.8/CD cents/kg/NN)
#   (content on/IN molybdenum/NN content/NN))
# (S
#   (cent_tariff 77.2/CD cents/kg/NN)
#   (content on/IN molybdenum/NN content/NN))
# (S
# ...
#   and/CC
#   case/NN
#   +/VBP
#   (cent_tariff 5.3/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 40/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 6/CD %/NN)
#   (content on/IN the/DT case/NN)
#   +/VBZ
#   (cent_tariff 5.3/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   $/$
#   (dollar_tariff 1.70/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 45/CD %/NN)
#   (content on/IN the/DT case/NN)
#   +/VBZ
#   (cent_tariff 35/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 76/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 6/CD %/NN)
#   (content on/IN the/DT case/NN)
#   +/VBZ
#   (cent_tariff 5.3/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   $/$
#   (dollar_tariff 2.70/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 45/CD %/NN)
#   (content on/IN the/DT case/NN)
#   +/VBZ
#   (cent_tariff 35/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 20/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 3/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   (cent_tariff 92/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 3/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   $/$
#   (dollar_tariff 4.20/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 45/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   $/$
#   (dollar_tariff 1.16/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 6/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   $/$
#   (dollar_tariff 2.19/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 6/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   $/$
#   (dollar_tariff 10.95/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 45/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   (cent_tariff 2.6/CD %/NN)
#   (content on/IN the/DT movement/NN)
#   and/CC
#   case/NN
#   +/VBP
#   (cent_tariff 3.6/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 24/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 4.5/CD %/NN)
#   (content on/IN the/DT case/NN)
#   +/VBZ
#   (cent_tariff 3.5/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   $/$
#   (dollar_tariff 1.50/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 45/CD %/NN)
#   (content on/IN the/DT case/NN)
#   +/VBZ
#   (cent_tariff 35/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 48/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 4.6/CD %/NN)
#   (content on/IN the/DT case/NN)
#   +/VBZ
#   (cent_tariff 3.5/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   $/$
#   (dollar_tariff 2.50/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 45/CD %/NN)
#   (content on/IN the/DT case/NN)
#   +/VBZ
#   (cent_tariff 35/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 24/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 4.6/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   $/$
#   (dollar_tariff 1.50/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 45/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   (cent_tariff 2.6/CD %/NN)
#   (content on/IN the/DT movement/NN)
#   and/CC
#   case/NN
#   +/VBP
#   (cent_tariff 3.5/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 20/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 4.3/CD %/NN)
#   (content on/IN the/DT movement/NN)
#   and/CC
#   case/NN
#   +/VBP
#   (cent_tariff 3.5/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   $/$
#   (dollar_tariff 3/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 65/CD %/NN)
#   (content on/IN the/DT movement/NN)
#   and/CC
#   case/NN
#   +/VBP
#   (cent_tariff 35/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 30/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 6.4/CD %/NN))
# (S
#   $/$
#   (dollar_tariff 3/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 65/CD %/NN))
# (S
#   (cent_tariff 30/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 4.3/CD %/NN)
#   (content on/IN the/DT movement/NN)
#   and/CC
#   case/NN
#   +/VBP
#   (cent_tariff 3.5/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   $/$
#   (dollar_tariff 4.50/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 65/CD %/NN)
#   (content on/IN the/DT movement/NN)
#   and/CC
#   case/NN
#   +/VBP
#   (cent_tariff 35/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 30/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 4.3/CD %/NN))
# (S
#   (cent_tariff 20/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 4.6/CD %/NN)
#   (content on/IN the/DT case/NN)
#   +/VBZ
#   (cent_tariff 3.5/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 75/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 45/CD %/NN)
#   (content on/IN the/DT case/NN)
#   +/VBZ
#   (cent_tariff 35/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 19/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 4.5/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   (cent_tariff 75/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 45/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   (cent_tariff 30/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 6.9/CD %/NN)
#   (content on/IN the/DT case/NN)
#   +/VBZ
#   (cent_tariff 5.3/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 30/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 6.9/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   (cent_tariff 60/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 6.9/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   $/$
#   (dollar_tariff 1.75/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 45/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   (cent_tariff 43/CD cents/NNS each/DT)
#   +/$
#   (cent_tariff 2.8/CD cents/jewel/NN)
#   over/IN
#   (dollar_tariff 7/CD)
#   +/JJ
#   (cent_tariff 3.7/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   $/$
#   (dollar_tariff 2.25/CD)
#   each/DT
#   +/NN
#   (cent_tariff 15/CD cents/jewel/NN)
#   over/IN
#   (dollar_tariff 7/CD)
#   +/JJ
#   (cent_tariff 60/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   (cent_tariff 15/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 6.4/CD %/NN))
# (S
#   (cent_tariff 10.5/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 4.4/CD %/NN))
# (S
#   $/$
#   (dollar_tariff 1.50/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 65/CD %/NN))
# (S
#   (cent_tariff 23/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 3.2/CD %/NN))
# (S
#   (cent_tariff 3.9/CD %/NN)
#   (content on/IN the/DT movement/NN)
#   and/CC
#   case+/VB
#   (cent_tariff 5.3/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 20/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 4.6/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   (cent_tariff 40/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 4.6/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   (cent_tariff 57/CD cents/NNS each/DT)
#   +/$
#   (cent_tariff 3.7/CD cents/jewel/NN)
#   over/IN
#   (dollar_tariff 7/CD)
#   +/JJ
#   (cent_tariff 4.9/CD %/NN)
#   (content on/IN the/DT case/NN))
# (S
#   (cent_tariff 17/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 2.5/CD %/NN)
#   +/CC
#   (cent_tariff 1/CD cents/jewel/NN))
# (S
#   $/$
#   (dollar_tariff 4.50/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 65/CD %/NN)
#   +/CC
#   (cent_tariff 25/CD cents/jewel/NN))
# (S
#   (cent_tariff 7.5/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 3.2/CD %/NN))
# (S (cent_tariff 5.6/CD %/NN) +/CC (cent_tariff 2/CD cents/jewel/NN))
# (S
#   (cent_tariff 36/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 5.6/CD %/NN)
#   +/CC
#   (cent_tariff 2/CD cents/jewel/NN))
# (S
#   (cent_tariff 3.9/CD %/NN)
#   (content on/IN the/DT apparatus/NN)
#   +/VBZ
#   (cent_tariff 5.3/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 15/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 2.3/CD %/NN)
#   +/CC
#   (cent_tariff 0.8/CD cents/jewel/NN))
# (S
#   (cent_tariff 15/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 4/CD %/NN)
#   +/CC
#   (cent_tariff 2.5/CD cents/jewel/NN))
# (S
#   (cent_tariff 10.5/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 2.8/CD %/NN)
#   +/CC
#   (cent_tariff 1.7/CD cents/jewel/NN))
# (S
#   $/$
#   (dollar_tariff 1.50/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 65/CD %/NN)
#   +/CC
#   (cent_tariff 25/CD cents/jewel/NN))
# (S
#   (cent_tariff 45/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 6.4/CD %/NN)
#   +/CC
#   (cent_tariff 2.5/CD cents/jewel/NN))
# (S
#   (cent_tariff 36/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 5.3/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   $/$
#   (dollar_tariff 1.50/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 35/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 72/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 5.3/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   $/$
#   (dollar_tariff 2.50/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 35/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 3.1/CD %/NN)
#   (content on/IN the/DT movement/NN)
#   +/VBZ
#   (cent_tariff 4.2/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 28/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 4.2/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 53/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 3.9/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S $/$ (dollar_tariff 10.75/CD) each/DT)
# (S $/$ (dollar_tariff 5.00/CD) each/DT)
# (S (cent_tariff 29/CD cents/NNS each/DT))
# (S $/$ (dollar_tariff 1.50/CD) each/DT)
# (S (cent_tariff 25/CD cents/NNS each/DT))
# (S (cent_tariff 57/CD cents/NNS each/DT))
# (S $/$ (dollar_tariff 2.50/CD) each/DT)
# (S $/$ (dollar_tariff 2.16/CD) each/DT)
# (S $/$ (dollar_tariff 1.51/CD) each/DT)
# (S $/$ (dollar_tariff 4/CD) each/DT)
# (S $/$ (dollar_tariff 1.80/CD) each/DT)
# (S $/$ (dollar_tariff 1.26/CD) each/DT)
# (S (cent_tariff 90/CD cents/NNS each/DT))
# (S $/$ (dollar_tariff 1.44/CD) each/DT)
# (S $/$ (dollar_tariff 1.00/CD) each/DT)
# (S $/$ (dollar_tariff 1.72/CD) each/DT)
# (S
#   (cent_tariff 3.9/CD %/NN)
#   (content on/IN the/DT movement/NN)
#   +/VBZ
#   (cent_tariff 5.3/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 30/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 5.3/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 75/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 35/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 7.5/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 3.2/CD %/NN)
#   (content on/IN the/DT movement/NN)
#   +/VBZ
#   (cent_tariff 2.6/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   $/$
#   (dollar_tariff 1.50/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 65/CD %/NN)
#   (content on/IN the/DT movement/NN)
#   +/VBZ
#   (cent_tariff 35/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 22/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 3.2/CD %/NN)
#   (content on/IN the/DT movement/NN)
#   +/VBZ
#   (cent_tariff 2.6/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   $/$
#   (dollar_tariff 4.50/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 65/CD %/NN)
#   (content on/IN the/DT movement/NN)
#   +/VBZ
#   (cent_tariff 35/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 20/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 3.5/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 12/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 5.1/CD %/NN)
#   (content on/IN the/DT movement/NN)
#   +/VBZ
#   (cent_tariff 4.2/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S
#   (cent_tariff 30/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 4.3/CD %/NN)
#   (content on/IN the/DT movement/NN)
#   +/VBZ
#   (cent_tariff 3.5/CD %/NN)
#   (content on/IN the/DT battery/NN))
# (S (cent_tariff 20/CD cents/NNS each/DT))
# (S (cent_tariff 75/CD cents/NNS each/DT))
# (S The/DT rate/NN applicable/JJ to/TO the/DT complete/JJ)
# (S
#   (cent_tariff 4.3/CD %/NN)
#   +/CC
#   (cent_tariff 1.7/CD cents/jewel/NN)
#   +/VBD
#   (dollar_tariff 0.2/CD)
#   cents/NNS
#   for/IN
#   each/DT
#   other/JJ
#   piece/NN
#   or/CC
#   part/NN)
# (S
#   (cent_tariff 65/CD %/NN)
#   +/CC
#   (cent_tariff 25/CD cents/jewel/NN)
#   +/VBD
#   (dollar_tariff 3/CD)
#   cents/NNS
#   for/IN
#   each/DT
#   other/JJ
#   piece/NN
#   or/CC
#   part/NN)
# (S
#   (cent_tariff 12/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 4.8/CD %/NN))
# (S
#   (cent_tariff 75/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 45/CD %/NN))
# (S
#   (cent_tariff 7/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 5.4/CD %/NN))
# (S
#   (cent_tariff 40/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 45/CD %/NN))
# (S
#   (cent_tariff 3.6/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 7.6/CD %/NN))
# (S
#   (cent_tariff 2.5/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 5.3/CD %/NN))
# (S
#   (cent_tariff 1.6/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 6.8/CD %/NN))
# (S
#   (cent_tariff 10/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 45/CD %/NN))
# (S
#   (cent_tariff 0.4/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 7.2/CD %/NN))
# (S
#   (cent_tariff 5/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 45/CD %/NN))
# (S (cent_tariff 12/CD cents/NNS each/DT))
# (S (cent_tariff 10/CD cents/NNS each/DT))
# (S (cent_tariff 38/CD cents/NNS each/DT))
# (S
#   (cent_tariff 6/CD %/NN)
#   +/CC
#   (cent_tariff 2.3/CD cents/jewel/NN)
#   +/VBD
#   (dollar_tariff 0.2/CD)
#   cents/NNS
#   for/IN
#   each/DT
#   other/JJ
#   piece/NN
#   or/CC
#   part/NN)
# (S $/$ (dollar_tariff 1/1/CD))
# (S (cent_tariff 10/CD cents/1/NN))
# (S
#   (cent_tariff 4.7/CD %/NN)
#   (content on/IN the/DT value/NN)
#   (content of/IN the/DT rifle/NN)
#   +/VBD
#   (cent_tariff 20/CD %/NN)
#   (content on/IN the/DT value/NN)
#   (content of/IN the/DT telescopic/NN)
#   sight/NN)
# (S
#   (cent_tariff 14/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 3/CD %/NN))
# (S
#   $/$
#   (dollar_tariff 3.50/CD)
#   each/DT
#   (dollar_tariff +/CD)
#   (cent_tariff 55/CD %/NN))
# (S
#   (cent_tariff 3.8/CD %/NN)
#   (content on/IN the/DT value/NN)
#   (content of/IN the/DT rifle/NN)
#   +/VBD
#   (cent_tariff 10/CD %/NN)
#   (content on/IN the/DT value/NN)
#   (content of/IN the/DT telescopic/NN)
#   sight/NN)
# (S
#   (cent_tariff 3.1/CD %/NN)
#   (content on/IN the/DT value/NN)
#   (content of/IN the/DT rifle/NN)
#   +/VBD
#   (cent_tariff 13/CD %/NN)
#   (content on/IN the/DT value/NN)
#   (content of/IN the/DT telescopic/NN)
#   sight/NN)
# (S (cent_tariff 10/CD cents/pack/NN) +/VBD (cent_tariff 20/CD %/NN))
# (S (cent_tariff 24/CD cents/NNS each/DT))
# (S (cent_tariff 5/CD cents/NNS each/DT))
# (S (cent_tariff 32/CD cents/NNS each/DT))
# (S (cent_tariff 22.4/CD cents/NNS each/DT))
# (S
#   (cent_tariff 2/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 50/CD %/NN))
# (S
#   (cent_tariff 0.2/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 7/CD %/NN))
# (S
#   (cent_tariff 1/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 50/CD %/NN))
# (S
#   (cent_tariff 0.3/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 3.6/CD %/NN))
# (S
#   (dollar_tariff 0.3/CD)
#   cents/line//JJ
#   gross/JJ
#   +/$
#   (cent_tariff 4.6/CD %/NN))
# (S
#   (dollar_tariff 1.5/CD)
#   cents/line//JJ
#   gross/JJ
#   +/$
#   (cent_tariff 25/CD %/NN))
# (S
#   (dollar_tariff 0.3/CD)
#   cents/line//JJ
#   gross/JJ
#   +/$
#   (cent_tariff 4.5/CD %/NN))
# (S
#   (dollar_tariff 0.18/CD)
#   cents/line//JJ
#   gross/JJ
#   +/$
#   (cent_tariff 2.5/CD %/NN))
# (S
#   (dollar_tariff 1.75/CD)
#   cents/line//JJ
#   gross/JJ
#   +/$
#   (cent_tariff 25/CD %/NN))
# (S
#   (cent_tariff 0.8/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 5.4/CD %/NN))
# (S
#   (cent_tariff 6/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 40/CD %/NN))
# (S
#   (cent_tariff 0.4/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 2.7/CD %/NN))
# (S
#   The/DT
#   rate/NN
#   applicable/JJ
#   to/TO
#   each/DT
#   article/NN
#   (content in/IN the/DT absence/NN)
#   (content of/IN this/DT subhead/NN)
#   ing/VBG)
# (S The/DT rate/NN applicable/JJ)
# (S
#   (cent_tariff 0.2/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 1.8/CD %/NN))
# (S
#   (cent_tariff 20/CD cents/thousand/NN)
#   +/VBD
#   (cent_tariff 3.5/CD %/NN))
# (S
#   $/$
#   (dollar_tariff 2.50/thousand/CD)
#   +/NNP
#   (cent_tariff 40/CD %/NN))
# (S
#   (cent_tariff 14/CD cents/gross/NN)
#   +/VBD
#   (cent_tariff 4.3/CD %/NN))
# (S (cent_tariff 50/CD cents/gross/NN) +/VBD (cent_tariff 30/CD %/NN))
# (S (cent_tariff 6/CD cents/gross/NN))
# (S
#   (cent_tariff 0.4/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 3.2/CD %/NN))
# (S
#   (cent_tariff 5/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 60/CD %/NN))
# (S
#   (cent_tariff 0.3/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 3.2/CD %/NN))
# (S
#   (cent_tariff 0.5/CD cents/NNS each/DT)
#   +/VBP
#   (cent_tariff 3/CD %/NN))
# (S
#   (cent_tariff 14.4/CD cents/gross/NN)
#   +/VBD
#   (cent_tariff 2/CD %/NN))
# (S $/$ (dollar_tariff 1.44/gross/CD) +/NNP (cent_tariff 25/CD %/NN))
# (S
#   (cent_tariff 28.8/CD cents/gross/NN)
#   +/VBD
#   (cent_tariff 4.6/CD %/NN))
# (S $/$ (dollar_tariff 2.88/gross/CD) +/NNP (cent_tariff 35/CD %/NN))
# (S
#   (cent_tariff 9.7/CD cents/gross/NN)
#   +/VBD
#   (cent_tariff 1.3/CD %/NN))

# %%
dat[dat.NonAdValorem!='   ']
# Out:
#         AdValorem AffectedPartners  \
# 49         1.96
# 50         0.30
# 51         0.12
# 68         1.63
# 72         0.30
# 73         0.12
# 90         1.64
# 92         0.28
# 93         0.11
# 110        1.53
# 115        1.46
# 117        2.32
# 119        3.23
# 120        0.94
# 138        4.16
# 140        0.58
# 158        2.57
# 160        0.38
# 178        1.71
# 180        0.37
# 198        1.62
# 200        0.19
# 218        0.84
# 220        0.42
# 238        1.85
# 240        1.51
# 258       13.29
# 260        1.05
# 278        9.26
# 394        0.94
# ...           ...              ...
# 133583
# 133601
# 133603     7.92
# 133611     4.41
# 133620   118.28
# 133623     0.41
# 133624
# 133641
# 133643
# 133660
# 133663
# 133666     6.17
# 133683    36.67
# 133686     1.85
# 133688     0.55
# 133692    40.40
# 133944
# 133961
# 133982
# 133999
# 134020
# 134037
# 134039     3.03
# 134056    35.32
# 134077     6.66
# 134094    55.63
# 134117     1.86
# 134134    33.26
# 134136     6.25
# 134153    51.52
#
#                                               MeasureName  \
# 49       Non-MFN duty rate for countries excluded from...
# 50            Most Favoured Nation duty rate treatement
# 51       Australia - United States Free Trade Agreemen...
# 68       Non-MFN duty rate for countries excluded from...
# 72            Most Favoured Nation duty rate treatement
# 73       Australia - United States Free Trade Agreemen...
# 90       Non-MFN duty rate for countries excluded from...
# 92            Most Favoured Nation duty rate treatement
# 93       Australia - United States Free Trade Agreemen...
# 110      Non-MFN duty rate for countries excluded from...
# 115      Non-MFN duty rate for countries excluded from...
# 117      Non-MFN duty rate for countries excluded from...
# 119      Non-MFN duty rate for countries excluded from...
# 120           Most Favoured Nation duty rate treatement
# 138      Non-MFN duty rate for countries excluded from...
# 140           Most Favoured Nation duty rate treatement
# 158      Non-MFN duty rate for countries excluded from...
# 160           Most Favoured Nation duty rate treatement
# 178      Non-MFN duty rate for countries excluded from...
# 180           Most Favoured Nation duty rate treatement
# 198      Non-MFN duty rate for countries excluded from...
# 200           Most Favoured Nation duty rate treatement
# 218      Non-MFN duty rate for countries excluded from...
# 220           Most Favoured Nation duty rate treatement
# 238      Non-MFN duty rate for countries excluded from...
# 240           Most Favoured Nation duty rate treatement
# 258      Non-MFN duty rate for countries excluded from...
# 260           Most Favoured Nation duty rate treatement
# 278      Non-MFN duty rate for countries excluded from...
# 394           Most Favoured Nation duty rate treatement
# ...                                                   ...
# 133583        Most Favoured Nation duty rate treatement
# 133601   Non-MFN duty rate for countries excluded from...
# 133603        Most Favoured Nation duty rate treatement
# 133611                      Preferential tariff for Korea
# 133620   Non-MFN duty rate for countries excluded from...
# 133623   Non-MFN duty rate for countries excluded from...
# 133624        Most Favoured Nation duty rate treatement
# 133641   Non-MFN duty rate for countries excluded from...
# 133643        Most Favoured Nation duty rate treatement
# 133660   Non-MFN duty rate for countries excluded from...
# 133663   Non-MFN duty rate for countries excluded from...
# 133666        Most Favoured Nation duty rate treatement
# 133683   Non-MFN duty rate for countries excluded from...
# 133686   Non-MFN duty rate for countries excluded from...
# 133688   Non-MFN duty rate for countries excluded from...
# 133692   Non-MFN duty rate for countries excluded from...
# 133944        Most Favoured Nation duty rate treatement
# 133961   Non-MFN duty rate for countries excluded from...
# 133982        Most Favoured Nation duty rate treatement
# 133999   Non-MFN duty rate for countries excluded from...
# 134020        Most Favoured Nation duty rate treatement
# 134037   Non-MFN duty rate for countries excluded from...
# 134039        Most Favoured Nation duty rate treatement
# 134056   Non-MFN duty rate for countries excluded from...
# 134077        Most Favoured Nation duty rate treatement
# 134094   Non-MFN duty rate for countries excluded from...
# 134117        Most Favoured Nation duty rate treatement
# 134134   Non-MFN duty rate for countries excluded from...
# 134136        Most Favoured Nation duty rate treatement
# 134153   Non-MFN duty rate for countries excluded from...
#
#                                              NonAdValorem Partner  \
# 49                                         6.6 cents/kg     N76
# 50                                           1 cents/kg     000
# 51                                         0.4 cents/kg     036
# 68                                         5.5 cents/kg     N76
# 72                                           1 cents/kg     000
# 73                                         0.4 cents/kg     036
# 90                                         5.5 cents/kg     N76
# 92                                           1 cents/kg     000
# 93                                         0.4 cents/kg     036
# 110                                        5.5 cents/kg     N76
# 115                                        4.4 cents/kg     N76
# 117                                        4.4 cents/kg     N76
# 119                                             $3/head     N76
# 120                                       68 cents/head     000
# 138                                             $3/head     N76
# 140                                      0.9 cents each     000
# 158                                        4 cents each     N76
# 160                                      0.9 cents each     000
# 178                                        4 cents each     N76
# 180                                      0.9 cents each     000
# 198                                        4 cents each     N76
# 200                                      0.9 cents each     000
# 218                                        4 cents each     N76
# 220                                      0.9 cents each     000
# 238                                        4 cents each     N76
# 240                                          2 cents/kg     000
# 258                                       17.6 cents/kg     N76
# 260                                          2 cents/kg     000
# 278                                       17.6 cents/kg     N76
# 394                                        4.4 cents/kg     000
# ...                                                   ...     ...
# 133583   The rate applicable to each article in the ab...   000
# 133601                                The rate applicable   N76
# 133603                            0.4 cents each + 2.7%     000
# 133611                            0.2 cents each + 1.8%     410
# 133620                               6 cents each + 40%     N76
# 133623                                   20 cents/gross     N76
# 133624                            0.4 cents each + 2.7%     000
# 133641                               6 cents each + 40%     N76
# 133643                         20 cents/thousand + 3.5%     000
# 133660                             $2.50/thousand + 40%     N76
# 133663                               6 cents each + 40%     N76
# 133666                            14 cents/gross + 4.3%     000
# 133683                             50 cents/gross + 30%     N76
# 133686                                   20 cents/gross     N76
# 133688                                    6 cents/gross     N76
# 133692                             50 cents/gross + 30%     N76
# 133944                            0.4 cents each + 3.2%     000
# 133961                               5 cents each + 60%     N76
# 133982                            0.3 cents each + 3.2%     000
# 133999                               5 cents each + 60%     N76
# 134020                              0.5 cents each + 3%     000
# 134037                               5 cents each + 60%     N76
# 134039                            14.4 cents/gross + 2%     000
# 134056                                $1.44/gross + 25%     N76
# 134077                          28.8 cents/gross + 4.6%     000
# 134094                                $2.88/gross + 35%     N76
# 134117                           9.7 cents/gross + 1.3%     000
# 134134                                $1.44/gross + 25%     N76
# 134136                          28.8 cents/gross + 4.6%     000
# 134153                                $2.88/gross + 35%     N76
#
#                                PartnerName  ProductCode  \
# 49       Non-MFN Countries for USA: 2006     01022920
# 50                                 World     01022940
# 51                             Australia     01022940
# 68       Non-MFN Countries for USA: 2006     01022940
# 72                                 World     01023900
# 73                             Australia     01023900
# 90       Non-MFN Countries for USA: 2006     01023900
# 92                                 World     01029000
# 93                             Australia     01029000
# 110      Non-MFN Countries for USA: 2006     01029000
# 115      Non-MFN Countries for USA: 2006     01039100
# 117      Non-MFN Countries for USA: 2006     01039200
# 119      Non-MFN Countries for USA: 2006     01041000
# 120                                World     01042000
# 138      Non-MFN Countries for USA: 2006     01042000
# 140                                World     01051100
# 158      Non-MFN Countries for USA: 2006     01051100
# 160                                World     01051200
# 178      Non-MFN Countries for USA: 2006     01051200
# 180                                World     01051300
# 198      Non-MFN Countries for USA: 2006     01051300
# 200                                World     01051400
# 218      Non-MFN Countries for USA: 2006     01051400
# 220                                World     01051500
# 238      Non-MFN Countries for USA: 2006     01051500
# 240                                World     01059400
# 258      Non-MFN Countries for USA: 2006     01059400
# 260                                World     01059900
# 278      Non-MFN Countries for USA: 2006     01059900
# 394                                World     02011005
# ...                                    ...          ...
# 133583                             World     96085000
# 133601   Non-MFN Countries for USA: 2006     96085000
# 133603                             World     96086000
# 133611                               Korea   96086000
# 133620   Non-MFN Countries for USA: 2006     96086000
# 133623   Non-MFN Countries for USA: 2006     96089100
# 133624                             World     96089920
# 133641   Non-MFN Countries for USA: 2006     96089920
# 133643                             World     96089930
# 133660   Non-MFN Countries for USA: 2006     96089930
# 133663   Non-MFN Countries for USA: 2006     96089940
# 133666                             World     96091000
# 133683   Non-MFN Countries for USA: 2006     96091000
# 133686   Non-MFN Countries for USA: 2006     96092020
# 133688   Non-MFN Countries for USA: 2006     96092040
# 133692   Non-MFN Countries for USA: 2006     96099080
# 133944                             World     96140025
# 133961   Non-MFN Countries for USA: 2006     96140025
# 133982                             World     96140028
# 133999   Non-MFN Countries for USA: 2006     96140028
# 134020                             World     96140098
# 134037   Non-MFN Countries for USA: 2006     96140098
# 134039                             World     96151110
# 134056   Non-MFN Countries for USA: 2006     96151110
# 134077                             World     96151130
# 134094   Non-MFN Countries for USA: 2006     96151130
# 134117                             World     96151920
# 134134   Non-MFN Countries for USA: 2006     96151920
# 134136                             World     96151940
# 134153   Non-MFN Countries for USA: 2006     96151940
#
#                                        ProductDescription
# 49           Cows imported specially for dairy purposes
# 50       Live cattle other than purebred or those impo...
# 51       Live cattle other than purebred or those impo...
# 68       Live cattle other than purebred or those impo...
# 72                                           Live buffalo
# 73                                           Live buffalo
# 90                                           Live buffalo
# 92                                    Live bovine animals
# 93                                    Live bovine animals
# 110                                   Live bovine animals
# 115                                            Live swine
# 117                                            Live swine
# 119                                          Live sheep
# 120                                          Live goats
# 138                                          Live goats
# 140          Live chickens weighing not over 185 g each
# 158          Live chickens weighing not over 185 g each
# 160      Live turkeys weighing not more than over 185 ...
# 178      Live turkeys weighing not more than over 185 ...
# 180                                            Live ducks
# 198                                            Live ducks
# 200                                            Live geese
# 218                                            Live geese
# 220                                     Live guinea fowls
# 238                                     Live guinea fowls
# 240                               Live Poultry;Chickens
# 258                               Live Poultry;Chickens
# 260                                            Live ducks
# 278                                            Live ducks
# 394                           Bovine carcasses and halves
# ...                                                   ...
# 133583                                       Sets of pens
# 133601                                       Sets of pens
# 133603                        Refills for ball point pens
# 133611                        Refills for ball point pens
# 133620                        Refills for ball point pens
# 133623                          Pen nibs and nib points
# 133624   Refill cartridges for pens (o/than ball point...
# 133641   Refill cartridges for pens (o/than ball point...
# 133643                        Balls for ball point pens
# 133660                        Balls for ball point pens
# 133663                                              Parts
# 133666                                  Pencils & crayons
# 133683                                  Pencils & crayons
# 133686                                       Pencil leads
# 133688                                       Pencil leads
# 133692         Pencils & crayons (o/than in rigid sheath)
# 133944   Smoking pipes (o/than roughly shaped blocks o...
# 133961   Smoking pipes (o/than roughly shaped blocks o...
# 133982          Smoking pipes and pipe bowls (o/than wood
# 133999          Smoking pipes and pipe bowls (o/than wood
# 134020   Cigar or cigarette holders o/than of metal; p...
# 134037   Cigar or cigarette holders o/than of metal; p...
# 134039                                              Combs
# 134056                                              Combs
# 134077                                              Combs
# 134094                                              Combs
# 134117                                              Combs
# 134134                                              Combs
# 134136                                              Combs
# 134153                                              Combs
#
# [5334 rows x 8 columns]
